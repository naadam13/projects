# %% [markdown]
# ## Import Library

# %%
import os
import pathlib
import pandas as pd
import numpy as np
import seaborn as sns
import matplotlib.pyplot as plt
import matplotlib.image as mpimg
from io import BytesIO
from PIL import Image
import cv2
import shutil
import random
import tensorflow as tf
from tensorflow import keras
import tensorflow_hub as hub
from tensorflow.keras.preprocessing.image import ImageDataGenerator
from tensorflow.keras.models import Sequential
from tensorflow.keras.callbacks import EarlyStopping
from tensorflow.keras.layers import Conv2D, MaxPool2D, Dense, Flatten, Dropout, BatchNormalization, GlobalAveragePooling2D, Activation, GlobalMaxPool2D, BatchNormalization
from tensorflow.keras.optimizers import Adam, Nadam
from tensorflow.keras import Input, Model
from tensorflow.keras.utils import plot_model
from sklearn.metrics import classification_report, confusion_matrix, ConfusionMatrixDisplay

# %%
# !pip install split-folders
# Out:
# Collecting split-folders
#   Downloading split_folders-0.5.1-py3-none-any.whl (8.4 kB)
# Installing collected packages: split-folders
# Successfully installed split-folders-0.5.1

# %%
import splitfolders

# %% [markdown]
# ## Data Loading

# %%
! pip install kaggle
# Out:
# Requirement already satisfied: kaggle in /usr/local/lib/python3.7/dist-packages (1.5.12)
# Requirement already satisfied: six>=1.10 in /usr/local/lib/python3.7/dist-packages (from kaggle) (1.15.0)
# Requirement already satisfied: python-dateutil in /usr/local/lib/python3.7/dist-packages (from kaggle) (2.8.2)
# Requirement already satisfied: urllib3 in /usr/local/lib/python3.7/dist-packages (from kaggle) (1.24.3)
# Requirement already satisfied: certifi in /usr/local/lib/python3.7/dist-packages (from kaggle) (2021.10.8)
# Requirement already satisfied: tqdm in /usr/local/lib/python3.7/dist-packages (from kaggle) (4.63.0)
# Requirement already satisfied: requests in /usr/local/lib/python3.7/dist-packages (from kaggle) (2.23.0)
# Requirement already satisfied: python-slugify in /usr/local/lib/python3.7/dist-packages (from kaggle) (6.1.1)
# Requirement already satisfied: text-unidecode>=1.3 in /usr/local/lib/python3.7/dist-packages (from python-slugify->kaggle) (1.3)
# Requirement already satisfied: chardet<4,>=3.0.2 in /usr/local/lib/python3.7/dist-packages (from requests->kaggle) (3.0.4)
# Requirement already satisfied: idna<3,>=2.5 in /usr/local/lib/python3.7/dist-packages (from requests->kaggle) (2.10)

# %%
! mkdir ~/.kaggle

# %%
from google.colab import drive
from google.colab import files
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %%
! pwd
# Out:
# /content

# %%
! cp /content/drive/MyDrive/kaggle.json ~/.kaggle/kaggle.json

# %%
! kaggle datasets download guy007/nutrientdeficiencysymptomsinrice
# Out:
# Downloading nutrientdeficiencysymptomsinrice.zip to /content
# 100% 988M/989M [00:08<00:00, 154MB/s]
# 100% 989M/989M [00:08<00:00, 125MB/s]

# %%
! unzip nutrientdeficiencysymptomsinrice
# Out:
# Archive:  nutrientdeficiencysymptomsinrice.zip
#   inflating: rice_plant_lacks_nutrients/Nitrogen(N)/untitled-1.JPG
#   inflating: rice_plant_lacks_nutrients/Nitrogen(N)/untitled-10.JPG
#   inflating: rice_plant_lacks_nutrients/Nitrogen(N)/untitled-100.JPG
#   inflating: rice_plant_lacks_nutrients/Nitrogen(N)/untitled-101.JPG
#   inflating: rice_plant_lacks_nutrients/Nitrogen(N)/untitled-102.JPG
#   inflating: rice_plant_lacks_nutrients/Nitrogen(N)/untitled-103.JPG
#   inflating: rice_plant_lacks_nutrients/Nitrogen(N)/untitled-104.JPG
#   inflating: rice_plant_lacks_nutrients/Nitrogen(N)/untitled-105.JPG
#   inflating: rice_plant_lacks_nutrients/Nitrogen(N)/untitled-106.JPG
#   inflating: rice_plant_lacks_nutrients/Nitrogen(N)/untitled-107.JPG
#   inflating: rice_plant_lacks_nutrients/Nitrogen(N)/untitled-108.JPG
#   inflating: rice_plant_lacks_nutrients/Nitrogen(N)/untitled-109.JPG
#   inflating: rice_plant_lacks_nutrients/Nitrogen(N)/untitled-11.JPG
#   inflating: rice_plant_lacks_nutrients/Nitrogen(N)/untitled-110.JPG
#   inflating: rice_plant_lacks_nutrients/Nitrogen(N)/untitled-111.JPG
#   inflating: rice_plant_lacks_nutrients/Nitrogen(N)/untitled-112.JPG
#   inflating: rice_plant_lacks_nutrients/Nitrogen(N)/untitled-113.JPG
#   inflating: rice_plant_lacks_nutrients/Nitrogen(N)/untitled-114.JPG
#   inflating: rice_plant_lacks_nutrients/Nitrogen(N)/untitled-115.JPG
#   inflating: rice_plant_lacks_nutrients/Nitrogen(N)/untitled-116.JPG
#   inflating: rice_plant_lacks_nutrients/Nitrogen(N)/untitled-117.JPG
#   inflating: rice_plant_lacks_nutrients/Nitrogen(N)/untitled-118.JPG
#   inflating: rice_plant_lacks_nutrients/Nitrogen(N)/untitled-119.JPG
#   inflating: rice_plant_lacks_nutrients/Nitrogen(N)/untitled-12.JPG
#   inflating: rice_plant_lacks_nutrients/Nitrogen(N)/untitled-120.JPG
#   inflating: rice_plant_lacks_nutrients/Nitrogen(N)/untitled-121.JPG
#   inflating: rice_plant_lacks_nutrients/Nitrogen(N)/untitled-122.JPG
#   inflating: rice_plant_lacks_nutrients/Nitrogen(N)/untitled-123.JPG
#   inflating: rice_plant_lacks_nutrients/Nitrogen(N)/untitled-124.JPG
#   inflating: rice_plant_lacks_nutrients/Nitrogen(N)/untitled-125.JPG
#   inflating: rice_plant_lacks_nutrients/Nitrogen(N)/untitled-126.JPG
#   inflating: rice_plant_lacks_nutrients/Nitrogen(N)/untitled-127.JPG
#   inflating: rice_plant_lacks_nutrients/Nitrogen(N)/untitled-128.JPG
#   inflating: rice_plant_lacks_nutrients/Nitrogen(N)/untitled-129.JPG
#   inflating: rice_plant_lacks_nutrients/Nitrogen(N)/untitled-13.JPG
#   inflating: rice_plant_lacks_nutrients/Nitrogen(N)/untitled-130.JPG
#   inflating: rice_plant_lacks_nutrients/Nitrogen(N)/untitled-131.JPG
#   inflating: rice_plant_lacks_nutrients/Nitrogen(N)/untitled-132.JPG
#   inflating: rice_plant_lacks_nutrients/Nitrogen(N)/untitled-133.JPG
#   inflating: rice_plant_lacks_nutrients/Nitrogen(N)/untitled-134.JPG
#   inflating: rice_plant_lacks_nutrients/Nitrogen(N)/untitled-135.JPG
#   inflating: rice_plant_lacks_nutrients/Nitrogen(N)/untitled-136.JPG
#   inflating: rice_plant_lacks_nutrients/Nitrogen(N)/untitled-137.JPG
#   inflating: rice_plant_lacks_nutrients/Nitrogen(N)/untitled-138.JPG
#   inflating: rice_plant_lacks_nutrients/Nitrogen(N)/untitled-139.JPG
#   inflating: rice_plant_lacks_nutrients/Nitrogen(N)/untitled-14.JPG
#   inflating: rice_plant_lacks_nutrients/Nitrogen(N)/untitled-140.JPG
#   inflating: rice_plant_lacks_nutrients/Nitrogen(N)/untitled-141.JPG
#   inflating: rice_plant_lacks_nutrients/Nitrogen(N)/untitled-142.JPG
#   inflating: rice_plant_lacks_nutrients/Nitrogen(N)/untitled-143.JPG
#   inflating: rice_plant_lacks_nutrients/Nitrogen(N)/untitled-144.JPG
#   inflating: rice_plant_lacks_nutrients/Nitrogen(N)/untitled-145.JPG
#   inflating: rice_plant_lacks_nutrients/Nitrogen(N)/untitled-146.JPG
#   inflating: rice_plant_lacks_nutrients/Nitrogen(N)/untitled-147.JPG
#   inflating: rice_plant_lacks_nutrients/Nitrogen(N)/untitled-148.JPG
#   inflating: rice_plant_lacks_nutrients/Nitrogen(N)/untitled-149.JPG
#   inflating: rice_plant_lacks_nutrients/Nitrogen(N)/untitled-15.JPG
#   inflating: rice_plant_lacks_nutrients/Nitrogen(N)/untitled-150.JPG
#   inflating: rice_plant_lacks_nutrients/Nitrogen(N)/untitled-151.JPG
#   inflating: rice_plant_lacks_nutrients/Nitrogen(N)/untitled-152.JPG
#   inflating: rice_plant_lacks_nutrients/Nitrogen(N)/untitled-153.JPG
#   inflating: rice_plant_lacks_nutrients/Nitrogen(N)/untitled-154.JPG
#   inflating: rice_plant_lacks_nutrients/Nitrogen(N)/untitled-155.JPG
#   inflating: rice_plant_lacks_nutrients/Nitrogen(N)/untitled-156.JPG
#   inflating: rice_plant_lacks_nutrients/Nitrogen(N)/untitled-157.JPG
#   inflating: rice_plant_lacks_nutrients/Nitrogen(N)/untitled-158.JPG
#   inflating: rice_plant_lacks_nutrients/Nitrogen(N)/untitled-159.JPG
#   inflating: rice_plant_lacks_nutrients/Nitrogen(N)/untitled-16.JPG
#   inflating: rice_plant_lacks_nutrients/Nitrogen(N)/untitled-160.JPG
#   inflating: rice_plant_lacks_nutrients/Nitrogen(N)/untitled-161.JPG
#   inflating: rice_plant_lacks_nutrients/Nitrogen(N)/untitled-162.JPG
#   inflating: rice_plant_lacks_nutrients/Nitrogen(N)/untitled-163.JPG
#   inflating: rice_plant_lacks_nutrients/Nitrogen(N)/untitled-164.JPG
#   inflating: rice_plant_lacks_nutrients/Nitrogen(N)/untitled-165.JPG
#   inflating: rice_plant_lacks_nutrients/Nitrogen(N)/untitled-166.JPG
#   inflating: rice_plant_lacks_nutrients/Nitrogen(N)/untitled-167.JPG
#   inflating: rice_plant_lacks_nutrients/Nitrogen(N)/untitled-168.JPG
#   inflating: rice_plant_lacks_nutrients/Nitrogen(N)/untitled-169.JPG
#   inflating: rice_plant_lacks_nutrients/Nitrogen(N)/untitled-17.JPG
#   inflating: rice_plant_lacks_nutrients/Nitrogen(N)/untitled-170.JPG
#   inflating: rice_plant_lacks_nutrients/Nitrogen(N)/untitled-171.JPG
#   inflating: rice_plant_lacks_nutrients/Nitrogen(N)/untitled-172.JPG
#   inflating: rice_plant_lacks_nutrients/Nitrogen(N)/untitled-173.JPG
#   inflating: rice_plant_lacks_nutrients/Nitrogen(N)/untitled-174.JPG
#   inflating: rice_plant_lacks_nutrients/Nitrogen(N)/untitled-175.JPG
#   inflating: rice_plant_lacks_nutrients/Nitrogen(N)/untitled-176.JPG
#   inflating: rice_plant_lacks_nutrients/Nitrogen(N)/untitled-177.JPG
#   inflating: rice_plant_lacks_nutrients/Nitrogen(N)/untitled-178.JPG
#   inflating: rice_plant_lacks_nutrients/Nitrogen(N)/untitled-179.JPG
#   inflating: rice_plant_lacks_nutrients/Nitrogen(N)/untitled-18.JPG
#   inflating: rice_plant_lacks_nutrients/Nitrogen(N)/untitled-180.JPG
#   inflating: rice_plant_lacks_nutrients/Nitrogen(N)/untitled-181.JPG
#   inflating: rice_plant_lacks_nutrients/Nitrogen(N)/untitled-182.JPG
#   inflating: rice_plant_lacks_nutrients/Nitrogen(N)/untitled-183.JPG
#   inflating: rice_plant_lacks_nutrients/Nitrogen(N)/untitled-184.JPG
#   inflating: rice_plant_lacks_nutrients/Nitrogen(N)/untitled-185.JPG
#   inflating: rice_plant_lacks_nutrients/Nitrogen(N)/untitled-186.JPG
#   inflating: rice_plant_lacks_nutrients/Nitrogen(N)/untitled-187.JPG
#   inflating: rice_plant_lacks_nutrients/Nitrogen(N)/untitled-188.JPG
#   inflating: rice_plant_lacks_nutrients/Nitrogen(N)/untitled-189.JPG
#   inflating: rice_plant_lacks_nutrients/Nitrogen(N)/untitled-19.JPG
#   inflating: rice_plant_lacks_nutrients/Nitrogen(N)/untitled-190.JPG
#   inflating: rice_plant_lacks_nutrients/Nitrogen(N)/untitled-191.JPG
#   inflating: rice_plant_lacks_nutrients/Nitrogen(N)/untitled-192.JPG
#   inflating: rice_plant_lacks_nutrients/Nitrogen(N)/untitled-193.JPG
#   inflating: rice_plant_lacks_nutrients/Nitrogen(N)/untitled-194.JPG
#   inflating: rice_plant_lacks_nutrients/Nitrogen(N)/untitled-195.JPG
#   inflating: rice_plant_lacks_nutrients/Nitrogen(N)/untitled-196.JPG
#   inflating: rice_plant_lacks_nutrients/Nitrogen(N)/untitled-197.JPG
#   inflating: rice_plant_lacks_nutrients/Nitrogen(N)/untitled-198.JPG
#   inflating: rice_plant_lacks_nutrients/Nitrogen(N)/untitled-199.JPG
#   inflating: rice_plant_lacks_nutrients/Nitrogen(N)/untitled-2.JPG
#   inflating: rice_plant_lacks_nutrients/Nitrogen(N)/untitled-20.JPG
#   inflating: rice_plant_lacks_nutrients/Nitrogen(N)/untitled-200.JPG
#   inflating: rice_plant_lacks_nutrients/Nitrogen(N)/untitled-201.JPG
#   inflating: rice_plant_lacks_nutrients/Nitrogen(N)/untitled-202.JPG
#   inflating: rice_plant_lacks_nutrients/Nitrogen(N)/untitled-203.JPG
#   inflating: rice_plant_lacks_nutrients/Nitrogen(N)/untitled-204.JPG
#   inflating: rice_plant_lacks_nutrients/Nitrogen(N)/untitled-205.JPG
#   inflating: rice_plant_lacks_nutrients/Nitrogen(N)/untitled-206.JPG
#   inflating: rice_plant_lacks_nutrients/Nitrogen(N)/untitled-207.JPG
#   inflating: rice_plant_lacks_nutrients/Nitrogen(N)/untitled-208.JPG
#   inflating: rice_plant_lacks_nutrients/Nitrogen(N)/untitled-209.JPG
#   inflating: rice_plant_lacks_nutrients/Nitrogen(N)/untitled-21.JPG
#   inflating: rice_plant_lacks_nutrients/Nitrogen(N)/untitled-210.JPG
#   inflating: rice_plant_lacks_nutrients/Nitrogen(N)/untitled-211.JPG
#   inflating: rice_plant_lacks_nutrients/Nitrogen(N)/untitled-212.JPG
#   inflating: rice_plant_lacks_nutrients/Nitrogen(N)/untitled-213.JPG
#   inflating: rice_plant_lacks_nutrients/Nitrogen(N)/untitled-214.JPG
#   inflating: rice_plant_lacks_nutrients/Nitrogen(N)/untitled-215.JPG
#   inflating: rice_plant_lacks_nutrients/Nitrogen(N)/untitled-216.JPG
#   inflating: rice_plant_lacks_nutrients/Nitrogen(N)/untitled-217.JPG
#   inflating: rice_plant_lacks_nutrients/Nitrogen(N)/untitled-218.JPG
#   inflating: rice_plant_lacks_nutrients/Nitrogen(N)/untitled-219.JPG
#   inflating: rice_plant_lacks_nutrients/Nitrogen(N)/untitled-22.JPG
#   inflating: rice_plant_lacks_nutrients/Nitrogen(N)/untitled-220.JPG
#   inflating: rice_plant_lacks_nutrients/Nitrogen(N)/untitled-221.JPG
#   inflating: rice_plant_lacks_nutrients/Nitrogen(N)/untitled-222.JPG
#   inflating: rice_plant_lacks_nutrients/Nitrogen(N)/untitled-223.JPG
#   inflating: rice_plant_lacks_nutrients/Nitrogen(N)/untitled-224.JPG
#   inflating: rice_plant_lacks_nutrients/Nitrogen(N)/untitled-225.JPG
#   inflating: rice_plant_lacks_nutrients/Nitrogen(N)/untitled-226.JPG
#   inflating: rice_plant_lacks_nutrients/Nitrogen(N)/untitled-227.JPG
#   inflating: rice_plant_lacks_nutrients/Nitrogen(N)/untitled-228.JPG
#   inflating: rice_plant_lacks_nutrients/Nitrogen(N)/untitled-229.JPG
#   inflating: rice_plant_lacks_nutrients/Nitrogen(N)/untitled-23.JPG
#   inflating: rice_plant_lacks_nutrients/Nitrogen(N)/untitled-230.JPG
#   inflating: rice_plant_lacks_nutrients/Nitrogen(N)/untitled-231.JPG
#   inflating: rice_plant_lacks_nutrients/Nitrogen(N)/untitled-232.JPG
#   inflating: rice_plant_lacks_nutrients/Nitrogen(N)/untitled-233.JPG
#   inflating: rice_plant_lacks_nutrients/Nitrogen(N)/untitled-234.JPG
#   inflating: rice_plant_lacks_nutrients/Nitrogen(N)/untitled-235.JPG
#   inflating: rice_plant_lacks_nutrients/Nitrogen(N)/untitled-236.JPG
#   inflating: rice_plant_lacks_nutrients/Nitrogen(N)/untitled-237.JPG
#   inflating: rice_plant_lacks_nutrients/Nitrogen(N)/untitled-238.JPG
#   inflating: rice_plant_lacks_nutrients/Nitrogen(N)/untitled-239.JPG
#   inflating: rice_plant_lacks_nutrients/Nitrogen(N)/untitled-24.JPG
#   inflating: rice_plant_lacks_nutrients/Nitrogen(N)/untitled-240.JPG
#   inflating: rice_plant_lacks_nutrients/Nitrogen(N)/untitled-241.JPG
#   inflating: rice_plant_lacks_nutrients/Nitrogen(N)/untitled-242.JPG
#   inflating: rice_plant_lacks_nutrients/Nitrogen(N)/untitled-243.JPG
#   inflating: rice_plant_lacks_nutrients/Nitrogen(N)/untitled-244.JPG
#   inflating: rice_plant_lacks_nutrients/Nitrogen(N)/untitled-245.JPG
#   inflating: rice_plant_lacks_nutrients/Nitrogen(N)/untitled-246.JPG
#   inflating: rice_plant_lacks_nutrients/Nitrogen(N)/untitled-247.JPG
#   inflating: rice_plant_lacks_nutrients/Nitrogen(N)/untitled-248.JPG
#   inflating: rice_plant_lacks_nutrients/Nitrogen(N)/untitled-249.JPG
#   inflating: rice_plant_lacks_nutrients/Nitrogen(N)/untitled-25.JPG
#   inflating: rice_plant_lacks_nutrients/Nitrogen(N)/untitled-250.JPG
#   inflating: rice_plant_lacks_nutrients/Nitrogen(N)/untitled-251.JPG
#   inflating: rice_plant_lacks_nutrients/Nitrogen(N)/untitled-252.JPG
#   inflating: rice_plant_lacks_nutrients/Nitrogen(N)/untitled-253.JPG
#   inflating: rice_plant_lacks_nutrients/Nitrogen(N)/untitled-254.JPG
#   inflating: rice_plant_lacks_nutrients/Nitrogen(N)/untitled-255.JPG
#   inflating: rice_plant_lacks_nutrients/Nitrogen(N)/untitled-256.JPG
#   inflating: rice_plant_lacks_nutrients/Nitrogen(N)/untitled-257.JPG
#   inflating: rice_plant_lacks_nutrients/Nitrogen(N)/untitled-258.JPG
#   inflating: rice_plant_lacks_nutrients/Nitrogen(N)/untitled-259.JPG
#   inflating: rice_plant_lacks_nutrients/Nitrogen(N)/untitled-26.JPG
#   inflating: rice_plant_lacks_nutrients/Nitrogen(N)/untitled-260.JPG
#   inflating: rice_plant_lacks_nutrients/Nitrogen(N)/untitled-261.JPG
#   inflating: rice_plant_lacks_nutrients/Nitrogen(N)/untitled-262.JPG
#   inflating: rice_plant_lacks_nutrients/Nitrogen(N)/untitled-263.JPG
#   inflating: rice_plant_lacks_nutrients/Nitrogen(N)/untitled-264.JPG
#   inflating: rice_plant_lacks_nutrients/Nitrogen(N)/untitled-265.JPG
#   inflating: rice_plant_lacks_nutrients/Nitrogen(N)/untitled-266.JPG
#   inflating: rice_plant_lacks_nutrients/Nitrogen(N)/untitled-267.JPG
#   inflating: rice_plant_lacks_nutrients/Nitrogen(N)/untitled-268.JPG
#   inflating: rice_plant_lacks_nutrients/Nitrogen(N)/untitled-269.JPG
#   inflating: rice_plant_lacks_nutrients/Nitrogen(N)/untitled-27.JPG
#   inflating: rice_plant_lacks_nutrients/Nitrogen(N)/untitled-270.JPG
#   inflating: rice_plant_lacks_nutrients/Nitrogen(N)/untitled-271.JPG
#   inflating: rice_plant_lacks_nutrients/Nitrogen(N)/untitled-272.JPG
#   inflating: rice_plant_lacks_nutrients/Nitrogen(N)/untitled-273.JPG
#   inflating: rice_plant_lacks_nutrients/Nitrogen(N)/untitled-274.JPG
#   inflating: rice_plant_lacks_nutrients/Nitrogen(N)/untitled-275.JPG
#   inflating: rice_plant_lacks_nutrients/Nitrogen(N)/untitled-276.JPG
#   inflating: rice_plant_lacks_nutrients/Nitrogen(N)/untitled-277.JPG
#   inflating: rice_plant_lacks_nutrients/Nitrogen(N)/untitled-278.JPG
#   inflating: rice_plant_lacks_nutrients/Nitrogen(N)/untitled-279.JPG
#   inflating: rice_plant_lacks_nutrients/Nitrogen(N)/untitled-28.JPG
#   inflating: rice_plant_lacks_nutrients/Nitrogen(N)/untitled-280.JPG
#   inflating: rice_plant_lacks_nutrients/Nitrogen(N)/untitled-281.JPG
#   inflating: rice_plant_lacks_nutrients/Nitrogen(N)/untitled-282.JPG
#   inflating: rice_plant_lacks_nutrients/Nitrogen(N)/untitled-283.JPG
#   inflating: rice_plant_lacks_nutrients/Nitrogen(N)/untitled-284.JPG
#   inflating: rice_plant_lacks_nutrients/Nitrogen(N)/untitled-285.JPG
#   inflating: rice_plant_lacks_nutrients/Nitrogen(N)/untitled-286.JPG
#   inflating: rice_plant_lacks_nutrients/Nitrogen(N)/untitled-287.JPG
#   inflating: rice_plant_lacks_nutrients/Nitrogen(N)/untitled-288.JPG
#   inflating: rice_plant_lacks_nutrients/Nitrogen(N)/untitled-289.JPG
#   inflating: rice_plant_lacks_nutrients/Nitrogen(N)/untitled-29.JPG
#   inflating: rice_plant_lacks_nutrients/Nitrogen(N)/untitled-290.JPG
#   inflating: rice_plant_lacks_nutrients/Nitrogen(N)/untitled-291.JPG
#   inflating: rice_plant_lacks_nutrients/Nitrogen(N)/untitled-292.JPG
#   inflating: rice_plant_lacks_nutrients/Nitrogen(N)/untitled-293.JPG
#   inflating: rice_plant_lacks_nutrients/Nitrogen(N)/untitled-294.JPG
#   inflating: rice_plant_lacks_nutrients/Nitrogen(N)/untitled-295.JPG
#   inflating: rice_plant_lacks_nutrients/Nitrogen(N)/untitled-296.JPG
#   inflating: rice_plant_lacks_nutrients/Nitrogen(N)/untitled-297.JPG
#   inflating: rice_plant_lacks_nutrients/Nitrogen(N)/untitled-298.JPG
#   inflating: rice_plant_lacks_nutrients/Nitrogen(N)/untitled-299.JPG
#   inflating: rice_plant_lacks_nutrients/Nitrogen(N)/untitled-3.JPG
#   inflating: rice_plant_lacks_nutrients/Nitrogen(N)/untitled-30.JPG
#   inflating: rice_plant_lacks_nutrients/Nitrogen(N)/untitled-300.JPG
#   inflating: rice_plant_lacks_nutrients/Nitrogen(N)/untitled-301.JPG
#   inflating: rice_plant_lacks_nutrients/Nitrogen(N)/untitled-302.JPG
#   inflating: rice_plant_lacks_nutrients/Nitrogen(N)/untitled-303.JPG
#   inflating: rice_plant_lacks_nutrients/Nitrogen(N)/untitled-304.JPG
#   inflating: rice_plant_lacks_nutrients/Nitrogen(N)/untitled-305.JPG
#   inflating: rice_plant_lacks_nutrients/Nitrogen(N)/untitled-306.JPG
#   inflating: rice_plant_lacks_nutrients/Nitrogen(N)/untitled-307.JPG
#   inflating: rice_plant_lacks_nutrients/Nitrogen(N)/untitled-308.JPG
#   inflating: rice_plant_lacks_nutrients/Nitrogen(N)/untitled-309.JPG
#   inflating: rice_plant_lacks_nutrients/Nitrogen(N)/untitled-31.JPG
#   inflating: rice_plant_lacks_nutrients/Nitrogen(N)/untitled-310.JPG
#   inflating: rice_plant_lacks_nutrients/Nitrogen(N)/untitled-311.JPG
#   inflating: rice_plant_lacks_nutrients/Nitrogen(N)/untitled-312.JPG
#   inflating: rice_plant_lacks_nutrients/Nitrogen(N)/untitled-313.JPG
#   inflating: rice_plant_lacks_nutrients/Nitrogen(N)/untitled-314.JPG
#   inflating: rice_plant_lacks_nutrients/Nitrogen(N)/untitled-315.JPG
#   inflating: rice_plant_lacks_nutrients/Nitrogen(N)/untitled-316.JPG
#   inflating: rice_plant_lacks_nutrients/Nitrogen(N)/untitled-317.JPG
#   inflating: rice_plant_lacks_nutrients/Nitrogen(N)/untitled-318.JPG
#   inflating: rice_plant_lacks_nutrients/Nitrogen(N)/untitled-319.JPG
#   inflating: rice_plant_lacks_nutrients/Nitrogen(N)/untitled-32.JPG
#   inflating: rice_plant_lacks_nutrients/Nitrogen(N)/untitled-320.JPG
#   inflating: rice_plant_lacks_nutrients/Nitrogen(N)/untitled-321.JPG
#   inflating: rice_plant_lacks_nutrients/Nitrogen(N)/untitled-322.JPG
#   inflating: rice_plant_lacks_nutrients/Nitrogen(N)/untitled-323.JPG
#   inflating: rice_plant_lacks_nutrients/Nitrogen(N)/untitled-324.JPG
#   inflating: rice_plant_lacks_nutrients/Nitrogen(N)/untitled-325.JPG
#   inflating: rice_plant_lacks_nutrients/Nitrogen(N)/untitled-326.JPG
#   inflating: rice_plant_lacks_nutrients/Nitrogen(N)/untitled-327.JPG
#   inflating: rice_plant_lacks_nutrients/Nitrogen(N)/untitled-328.JPG
#   inflating: rice_plant_lacks_nutrients/Nitrogen(N)/untitled-329.JPG
#   inflating: rice_plant_lacks_nutrients/Nitrogen(N)/untitled-33.JPG
#   inflating: rice_plant_lacks_nutrients/Nitrogen(N)/untitled-330.JPG
#   inflating: rice_plant_lacks_nutrients/Nitrogen(N)/untitled-331.JPG
#   inflating: rice_plant_lacks_nutrients/Nitrogen(N)/untitled-332.JPG
#   inflating: rice_plant_lacks_nutrients/Nitrogen(N)/untitled-333.JPG
#   inflating: rice_plant_lacks_nutrients/Nitrogen(N)/untitled-334.JPG
#   inflating: rice_plant_lacks_nutrients/Nitrogen(N)/untitled-335.JPG
#   inflating: rice_plant_lacks_nutrients/Nitrogen(N)/untitled-336.JPG
#   inflating: rice_plant_lacks_nutrients/Nitrogen(N)/untitled-337.JPG
#   inflating: rice_plant_lacks_nutrients/Nitrogen(N)/untitled-338.JPG
#   inflating: rice_plant_lacks_nutrients/Nitrogen(N)/untitled-339.JPG
#   inflating: rice_plant_lacks_nutrients/Nitrogen(N)/untitled-34.JPG
#   inflating: rice_plant_lacks_nutrients/Nitrogen(N)/untitled-340.JPG
#   inflating: rice_plant_lacks_nutrients/Nitrogen(N)/untitled-341.JPG
#   inflating: rice_plant_lacks_nutrients/Nitrogen(N)/untitled-342.JPG
#   inflating: rice_plant_lacks_nutrients/Nitrogen(N)/untitled-343.JPG
#   inflating: rice_plant_lacks_nutrients/Nitrogen(N)/untitled-344.JPG
#   inflating: rice_plant_lacks_nutrients/Nitrogen(N)/untitled-345.JPG
#   inflating: rice_plant_lacks_nutrients/Nitrogen(N)/untitled-346.JPG
#   inflating: rice_plant_lacks_nutrients/Nitrogen(N)/untitled-347.JPG
#   inflating: rice_plant_lacks_nutrients/Nitrogen(N)/untitled-348.JPG
#   inflating: rice_plant_lacks_nutrients/Nitrogen(N)/untitled-349.JPG
#   inflating: rice_plant_lacks_nutrients/Nitrogen(N)/untitled-35.JPG
#   inflating: rice_plant_lacks_nutrients/Nitrogen(N)/untitled-350.JPG
#   inflating: rice_plant_lacks_nutrients/Nitrogen(N)/untitled-351.JPG
#   inflating: rice_plant_lacks_nutrients/Nitrogen(N)/untitled-352.JPG
#   inflating: rice_plant_lacks_nutrients/Nitrogen(N)/untitled-353.JPG
#   inflating: rice_plant_lacks_nutrients/Nitrogen(N)/untitled-354.JPG
#   inflating: rice_plant_lacks_nutrients/Nitrogen(N)/untitled-355.JPG
#   inflating: rice_plant_lacks_nutrients/Nitrogen(N)/untitled-356.JPG
#   inflating: rice_plant_lacks_nutrients/Nitrogen(N)/untitled-357.JPG
#   inflating: rice_plant_lacks_nutrients/Nitrogen(N)/untitled-358.JPG
#   inflating: rice_plant_lacks_nutrients/Nitrogen(N)/untitled-359.JPG
#   inflating: rice_plant_lacks_nutrients/Nitrogen(N)/untitled-36.JPG
#   inflating: rice_plant_lacks_nutrients/Nitrogen(N)/untitled-360.JPG
#   inflating: rice_plant_lacks_nutrients/Nitrogen(N)/untitled-361.JPG
#   inflating: rice_plant_lacks_nutrients/Nitrogen(N)/untitled-362.JPG
#   inflating: rice_plant_lacks_nutrients/Nitrogen(N)/untitled-363.JPG
#   inflating: rice_plant_lacks_nutrients/Nitrogen(N)/untitled-364.JPG
#   inflating: rice_plant_lacks_nutrients/Nitrogen(N)/untitled-365.JPG
#   inflating: rice_plant_lacks_nutrients/Nitrogen(N)/untitled-366.JPG
#   inflating: rice_plant_lacks_nutrients/Nitrogen(N)/untitled-367.JPG
#   inflating: rice_plant_lacks_nutrients/Nitrogen(N)/untitled-368.JPG
#   inflating: rice_plant_lacks_nutrients/Nitrogen(N)/untitled-369.JPG
#   inflating: rice_plant_lacks_nutrients/Nitrogen(N)/untitled-37.JPG
#   inflating: rice_plant_lacks_nutrients/Nitrogen(N)/untitled-370.JPG
#   inflating: rice_plant_lacks_nutrients/Nitrogen(N)/untitled-371.JPG
#   inflating: rice_plant_lacks_nutrients/Nitrogen(N)/untitled-372.JPG
#   inflating: rice_plant_lacks_nutrients/Nitrogen(N)/untitled-373.JPG
#   inflating: rice_plant_lacks_nutrients/Nitrogen(N)/untitled-374.JPG
#   inflating: rice_plant_lacks_nutrients/Nitrogen(N)/untitled-375.JPG
#   inflating: rice_plant_lacks_nutrients/Nitrogen(N)/untitled-376.JPG
#   inflating: rice_plant_lacks_nutrients/Nitrogen(N)/untitled-377.JPG
#   inflating: rice_plant_lacks_nutrients/Nitrogen(N)/untitled-378.JPG
#   inflating: rice_plant_lacks_nutrients/Nitrogen(N)/untitled-379.JPG
#   inflating: rice_plant_lacks_nutrients/Nitrogen(N)/untitled-38.JPG
#   inflating: rice_plant_lacks_nutrients/Nitrogen(N)/untitled-380.JPG
#   inflating: rice_plant_lacks_nutrients/Nitrogen(N)/untitled-381.JPG
#   inflating: rice_plant_lacks_nutrients/Nitrogen(N)/untitled-382.JPG
#   inflating: rice_plant_lacks_nutrients/Nitrogen(N)/untitled-383.JPG
#   inflating: rice_plant_lacks_nutrients/Nitrogen(N)/untitled-384.JPG
#   inflating: rice_plant_lacks_nutrients/Nitrogen(N)/untitled-385.JPG
#   inflating: rice_plant_lacks_nutrients/Nitrogen(N)/untitled-386.JPG
#   inflating: rice_plant_lacks_nutrients/Nitrogen(N)/untitled-387.JPG
#   inflating: rice_plant_lacks_nutrients/Nitrogen(N)/untitled-388.JPG
#   inflating: rice_plant_lacks_nutrients/Nitrogen(N)/untitled-389.JPG
#   inflating: rice_plant_lacks_nutrients/Nitrogen(N)/untitled-39.JPG
#   inflating: rice_plant_lacks_nutrients/Nitrogen(N)/untitled-390.JPG
#   inflating: rice_plant_lacks_nutrients/Nitrogen(N)/untitled-391.JPG
#   inflating: rice_plant_lacks_nutrients/Nitrogen(N)/untitled-392.JPG
#   inflating: rice_plant_lacks_nutrients/Nitrogen(N)/untitled-393.JPG
#   inflating: rice_plant_lacks_nutrients/Nitrogen(N)/untitled-394.JPG
#   inflating: rice_plant_lacks_nutrients/Nitrogen(N)/untitled-395.JPG
#   inflating: rice_plant_lacks_nutrients/Nitrogen(N)/untitled-396.JPG
#   inflating: rice_plant_lacks_nutrients/Nitrogen(N)/untitled-397.JPG
#   inflating: rice_plant_lacks_nutrients/Nitrogen(N)/untitled-398.JPG
#   inflating: rice_plant_lacks_nutrients/Nitrogen(N)/untitled-399.JPG
#   inflating: rice_plant_lacks_nutrients/Nitrogen(N)/untitled-4.JPG
#   inflating: rice_plant_lacks_nutrients/Nitrogen(N)/untitled-40.JPG
#   inflating: rice_plant_lacks_nutrients/Nitrogen(N)/untitled-400.JPG
#   inflating: rice_plant_lacks_nutrients/Nitrogen(N)/untitled-401.JPG
#   inflating: rice_plant_lacks_nutrients/Nitrogen(N)/untitled-402.JPG
#   inflating: rice_plant_lacks_nutrients/Nitrogen(N)/untitled-403.JPG
#   inflating: rice_plant_lacks_nutrients/Nitrogen(N)/untitled-404.JPG
#   inflating: rice_plant_lacks_nutrients/Nitrogen(N)/untitled-405.JPG
#   inflating: rice_plant_lacks_nutrients/Nitrogen(N)/untitled-406.JPG
#   inflating: rice_plant_lacks_nutrients/Nitrogen(N)/untitled-407.JPG
#   inflating: rice_plant_lacks_nutrients/Nitrogen(N)/untitled-408.JPG
#   inflating: rice_plant_lacks_nutrients/Nitrogen(N)/untitled-409.JPG
#   inflating: rice_plant_lacks_nutrients/Nitrogen(N)/untitled-41.JPG
#   inflating: rice_plant_lacks_nutrients/Nitrogen(N)/untitled-410.JPG
#   inflating: rice_plant_lacks_nutrients/Nitrogen(N)/untitled-411.JPG
#   inflating: rice_plant_lacks_nutrients/Nitrogen(N)/untitled-412.JPG
#   inflating: rice_plant_lacks_nutrients/Nitrogen(N)/untitled-413.JPG
#   inflating: rice_plant_lacks_nutrients/Nitrogen(N)/untitled-414.JPG
#   inflating: rice_plant_lacks_nutrients/Nitrogen(N)/untitled-415.JPG
#   inflating: rice_plant_lacks_nutrients/Nitrogen(N)/untitled-416.JPG
#   inflating: rice_plant_lacks_nutrients/Nitrogen(N)/untitled-417.JPG
#   inflating: rice_plant_lacks_nutrients/Nitrogen(N)/untitled-418.JPG
#   inflating: rice_plant_lacks_nutrients/Nitrogen(N)/untitled-419.JPG
#   inflating: rice_plant_lacks_nutrients/Nitrogen(N)/untitled-42.JPG
#   inflating: rice_plant_lacks_nutrients/Nitrogen(N)/untitled-420.JPG
#   inflating: rice_plant_lacks_nutrients/Nitrogen(N)/untitled-421.JPG
#   inflating: rice_plant_lacks_nutrients/Nitrogen(N)/untitled-422.JPG
#   inflating: rice_plant_lacks_nutrients/Nitrogen(N)/untitled-423.JPG
#   inflating: rice_plant_lacks_nutrients/Nitrogen(N)/untitled-424.JPG
#   inflating: rice_plant_lacks_nutrients/Nitrogen(N)/untitled-425.JPG
#   inflating: rice_plant_lacks_nutrients/Nitrogen(N)/untitled-426.JPG
#   inflating: rice_plant_lacks_nutrients/Nitrogen(N)/untitled-427.JPG
#   inflating: rice_plant_lacks_nutrients/Nitrogen(N)/untitled-428.JPG
#   inflating: rice_plant_lacks_nutrients/Nitrogen(N)/untitled-429.JPG
#   inflating: rice_plant_lacks_nutrients/Nitrogen(N)/untitled-43.JPG
#   inflating: rice_plant_lacks_nutrients/Nitrogen(N)/untitled-430.JPG
#   inflating: rice_plant_lacks_nutrients/Nitrogen(N)/untitled-431.JPG
#   inflating: rice_plant_lacks_nutrients/Nitrogen(N)/untitled-432.JPG
#   inflating: rice_plant_lacks_nutrients/Nitrogen(N)/untitled-433.JPG
#   inflating: rice_plant_lacks_nutrients/Nitrogen(N)/untitled-434.JPG
#   inflating: rice_plant_lacks_nutrients/Nitrogen(N)/untitled-435.JPG
#   inflating: rice_plant_lacks_nutrients/Nitrogen(N)/untitled-436.JPG
#   inflating: rice_plant_lacks_nutrients/Nitrogen(N)/untitled-437.JPG
#   inflating: rice_plant_lacks_nutrients/Nitrogen(N)/untitled-438.JPG
#   inflating: rice_plant_lacks_nutrients/Nitrogen(N)/untitled-439.JPG
#   inflating: rice_plant_lacks_nutrients/Nitrogen(N)/untitled-44.JPG
#   inflating: rice_plant_lacks_nutrients/Nitrogen(N)/untitled-440.JPG
#   inflating: rice_plant_lacks_nutrients/Nitrogen(N)/untitled-45.JPG
#   inflating: rice_plant_lacks_nutrients/Nitrogen(N)/untitled-46.JPG
#   inflating: rice_plant_lacks_nutrients/Nitrogen(N)/untitled-47.JPG
#   inflating: rice_plant_lacks_nutrients/Nitrogen(N)/untitled-48.JPG
#   inflating: rice_plant_lacks_nutrients/Nitrogen(N)/untitled-49.JPG
#   inflating: rice_plant_lacks_nutrients/Nitrogen(N)/untitled-5.JPG
#   inflating: rice_plant_lacks_nutrients/Nitrogen(N)/untitled-50.JPG
#   inflating: rice_plant_lacks_nutrients/Nitrogen(N)/untitled-51.JPG
#   inflating: rice_plant_lacks_nutrients/Nitrogen(N)/untitled-52.JPG
#   inflating: rice_plant_lacks_nutrients/Nitrogen(N)/untitled-53.JPG
#   inflating: rice_plant_lacks_nutrients/Nitrogen(N)/untitled-54.JPG
#   inflating: rice_plant_lacks_nutrients/Nitrogen(N)/untitled-55.JPG
#   inflating: rice_plant_lacks_nutrients/Nitrogen(N)/untitled-56.JPG
#   inflating: rice_plant_lacks_nutrients/Nitrogen(N)/untitled-57.JPG
#   inflating: rice_plant_lacks_nutrients/Nitrogen(N)/untitled-58.JPG
#   inflating: rice_plant_lacks_nutrients/Nitrogen(N)/untitled-59.JPG
#   inflating: rice_plant_lacks_nutrients/Nitrogen(N)/untitled-6.JPG
#   inflating: rice_plant_lacks_nutrients/Nitrogen(N)/untitled-60.JPG
#   inflating: rice_plant_lacks_nutrients/Nitrogen(N)/untitled-61.JPG
#   inflating: rice_plant_lacks_nutrients/Nitrogen(N)/untitled-62.JPG
#   inflating: rice_plant_lacks_nutrients/Nitrogen(N)/untitled-63.JPG
#   inflating: rice_plant_lacks_nutrients/Nitrogen(N)/untitled-64.JPG
#   inflating: rice_plant_lacks_nutrients/Nitrogen(N)/untitled-65.JPG
#   inflating: rice_plant_lacks_nutrients/Nitrogen(N)/untitled-66.JPG
#   inflating: rice_plant_lacks_nutrients/Nitrogen(N)/untitled-67.JPG
#   inflating: rice_plant_lacks_nutrients/Nitrogen(N)/untitled-68.JPG
#   inflating: rice_plant_lacks_nutrients/Nitrogen(N)/untitled-69.JPG
#   inflating: rice_plant_lacks_nutrients/Nitrogen(N)/untitled-7.JPG
#   inflating: rice_plant_lacks_nutrients/Nitrogen(N)/untitled-70.JPG
#   inflating: rice_plant_lacks_nutrients/Nitrogen(N)/untitled-71.JPG
#   inflating: rice_plant_lacks_nutrients/Nitrogen(N)/untitled-72.JPG
#   inflating: rice_plant_lacks_nutrients/Nitrogen(N)/untitled-73.JPG
#   inflating: rice_plant_lacks_nutrients/Nitrogen(N)/untitled-74.JPG
#   inflating: rice_plant_lacks_nutrients/Nitrogen(N)/untitled-75.JPG
#   inflating: rice_plant_lacks_nutrients/Nitrogen(N)/untitled-76.JPG
#   inflating: rice_plant_lacks_nutrients/Nitrogen(N)/untitled-77.JPG
#   inflating: rice_plant_lacks_nutrients/Nitrogen(N)/untitled-78.JPG
#   inflating: rice_plant_lacks_nutrients/Nitrogen(N)/untitled-79.JPG
#   inflating: rice_plant_lacks_nutrients/Nitrogen(N)/untitled-8.JPG
#   inflating: rice_plant_lacks_nutrients/Nitrogen(N)/untitled-80.JPG
#   inflating: rice_plant_lacks_nutrients/Nitrogen(N)/untitled-81.JPG
#   inflating: rice_plant_lacks_nutrients/Nitrogen(N)/untitled-82.JPG
#   inflating: rice_plant_lacks_nutrients/Nitrogen(N)/untitled-83.JPG
#   inflating: rice_plant_lacks_nutrients/Nitrogen(N)/untitled-84.JPG
#   inflating: rice_plant_lacks_nutrients/Nitrogen(N)/untitled-85.JPG
#   inflating: rice_plant_lacks_nutrients/Nitrogen(N)/untitled-86.JPG
#   inflating: rice_plant_lacks_nutrients/Nitrogen(N)/untitled-87.JPG
#   inflating: rice_plant_lacks_nutrients/Nitrogen(N)/untitled-88.JPG
#   inflating: rice_plant_lacks_nutrients/Nitrogen(N)/untitled-89.JPG
#   inflating: rice_plant_lacks_nutrients/Nitrogen(N)/untitled-9.JPG
#   inflating: rice_plant_lacks_nutrients/Nitrogen(N)/untitled-90.JPG
#   inflating: rice_plant_lacks_nutrients/Nitrogen(N)/untitled-91.JPG
#   inflating: rice_plant_lacks_nutrients/Nitrogen(N)/untitled-92.JPG
#   inflating: rice_plant_lacks_nutrients/Nitrogen(N)/untitled-93.JPG
#   inflating: rice_plant_lacks_nutrients/Nitrogen(N)/untitled-94.JPG
#   inflating: rice_plant_lacks_nutrients/Nitrogen(N)/untitled-95.JPG
#   inflating: rice_plant_lacks_nutrients/Nitrogen(N)/untitled-96.JPG
#   inflating: rice_plant_lacks_nutrients/Nitrogen(N)/untitled-97.JPG
#   inflating: rice_plant_lacks_nutrients/Nitrogen(N)/untitled-98.JPG
#   inflating: rice_plant_lacks_nutrients/Nitrogen(N)/untitled-99.JPG
#   inflating: rice_plant_lacks_nutrients/Phosphorus(P)/IMG_3784.JPG
#   inflating: rice_plant_lacks_nutrients/Phosphorus(P)/IMG_3785.JPG
#   inflating: rice_plant_lacks_nutrients/Phosphorus(P)/IMG_3786.JPG
#   inflating: rice_plant_lacks_nutrients/Phosphorus(P)/IMG_3787.JPG
#   inflating: rice_plant_lacks_nutrients/Phosphorus(P)/IMG_3788.JPG
#   inflating: rice_plant_lacks_nutrients/Phosphorus(P)/IMG_3789.JPG
#   inflating: rice_plant_lacks_nutrients/Phosphorus(P)/IMG_3791.JPG
#   inflating: rice_plant_lacks_nutrients/Phosphorus(P)/IMG_3792.JPG
#   inflating: rice_plant_lacks_nutrients/Phosphorus(P)/IMG_3793.JPG
#   inflating: rice_plant_lacks_nutrients/Phosphorus(P)/IMG_3794.JPG
#   inflating: rice_plant_lacks_nutrients/Phosphorus(P)/IMG_3795.JPG
#   inflating: rice_plant_lacks_nutrients/Phosphorus(P)/IMG_3796.JPG
#   inflating: rice_plant_lacks_nutrients/Phosphorus(P)/IMG_3797.JPG
#   inflating: rice_plant_lacks_nutrients/Phosphorus(P)/IMG_3798.JPG
#   inflating: rice_plant_lacks_nutrients/Phosphorus(P)/IMG_3799.JPG
#   inflating: rice_plant_lacks_nutrients/Phosphorus(P)/IMG_3800.JPG
#   inflating: rice_plant_lacks_nutrients/Phosphorus(P)/IMG_3801.JPG
#   inflating: rice_plant_lacks_nutrients/Phosphorus(P)/IMG_3802.JPG
#   inflating: rice_plant_lacks_nutrients/Phosphorus(P)/IMG_3803.JPG
#   inflating: rice_plant_lacks_nutrients/Phosphorus(P)/IMG_3805.JPG
#   inflating: rice_plant_lacks_nutrients/Phosphorus(P)/IMG_3806.JPG
#   inflating: rice_plant_lacks_nutrients/Phosphorus(P)/IMG_3807.JPG
#   inflating: rice_plant_lacks_nutrients/Phosphorus(P)/IMG_3808.JPG
#   inflating: rice_plant_lacks_nutrients/Phosphorus(P)/IMG_3809.JPG
#   inflating: rice_plant_lacks_nutrients/Phosphorus(P)/IMG_3810.JPG
#   inflating: rice_plant_lacks_nutrients/Phosphorus(P)/IMG_3811.JPG
#   inflating: rice_plant_lacks_nutrients/Phosphorus(P)/IMG_3812.JPG
#   inflating: rice_plant_lacks_nutrients/Phosphorus(P)/IMG_3813.JPG
#   inflating: rice_plant_lacks_nutrients/Phosphorus(P)/IMG_3814.JPG
#   inflating: rice_plant_lacks_nutrients/Phosphorus(P)/IMG_3815.JPG
#   inflating: rice_plant_lacks_nutrients/Phosphorus(P)/IMG_3816.JPG
#   inflating: rice_plant_lacks_nutrients/Phosphorus(P)/IMG_3817.JPG
#   inflating: rice_plant_lacks_nutrients/Phosphorus(P)/IMG_3818.JPG
#   inflating: rice_plant_lacks_nutrients/Phosphorus(P)/IMG_3819.JPG
#   inflating: rice_plant_lacks_nutrients/Phosphorus(P)/IMG_3820.JPG
#   inflating: rice_plant_lacks_nutrients/Phosphorus(P)/IMG_3821.JPG
#   inflating: rice_plant_lacks_nutrients/Phosphorus(P)/IMG_3822.JPG
#   inflating: rice_plant_lacks_nutrients/Phosphorus(P)/IMG_3823.JPG
#   inflating: rice_plant_lacks_nutrients/Phosphorus(P)/IMG_3824.JPG
#   inflating: rice_plant_lacks_nutrients/Phosphorus(P)/IMG_3825.JPG
#   inflating: rice_plant_lacks_nutrients/Phosphorus(P)/IMG_3826.JPG
#   inflating: rice_plant_lacks_nutrients/Phosphorus(P)/IMG_3827.JPG
#   inflating: rice_plant_lacks_nutrients/Phosphorus(P)/IMG_3828.JPG
#   inflating: rice_plant_lacks_nutrients/Phosphorus(P)/IMG_3829.JPG
#   inflating: rice_plant_lacks_nutrients/Phosphorus(P)/IMG_3830.JPG
#   inflating: rice_plant_lacks_nutrients/Phosphorus(P)/IMG_4087.JPG
#   inflating: rice_plant_lacks_nutrients/Phosphorus(P)/IMG_4088.JPG
#   inflating: rice_plant_lacks_nutrients/Phosphorus(P)/IMG_4089.JPG
#   inflating: rice_plant_lacks_nutrients/Phosphorus(P)/IMG_4090.JPG
#   inflating: rice_plant_lacks_nutrients/Phosphorus(P)/IMG_4091.JPG
#   inflating: rice_plant_lacks_nutrients/Phosphorus(P)/IMG_4092.JPG
#   inflating: rice_plant_lacks_nutrients/Phosphorus(P)/IMG_4093.JPG
#   inflating: rice_plant_lacks_nutrients/Phosphorus(P)/IMG_4094.JPG
#   inflating: rice_plant_lacks_nutrients/Phosphorus(P)/IMG_4095.JPG
#   inflating: rice_plant_lacks_nutrients/Phosphorus(P)/IMG_4096.JPG
#   inflating: rice_plant_lacks_nutrients/Phosphorus(P)/IMG_4097.JPG
#   inflating: rice_plant_lacks_nutrients/Phosphorus(P)/IMG_4098.JPG
#   inflating: rice_plant_lacks_nutrients/Phosphorus(P)/IMG_4099.JPG
#   inflating: rice_plant_lacks_nutrients/Phosphorus(P)/IMG_4100.JPG
#   inflating: rice_plant_lacks_nutrients/Phosphorus(P)/IMG_4101.JPG
#   inflating: rice_plant_lacks_nutrients/Phosphorus(P)/IMG_4102.JPG
#   inflating: rice_plant_lacks_nutrients/Phosphorus(P)/IMG_4103.JPG
#   inflating: rice_plant_lacks_nutrients/Phosphorus(P)/IMG_4104.JPG
#   inflating: rice_plant_lacks_nutrients/Phosphorus(P)/IMG_4105.JPG
#   inflating: rice_plant_lacks_nutrients/Phosphorus(P)/IMG_4106.JPG
#   inflating: rice_plant_lacks_nutrients/Phosphorus(P)/IMG_4107.JPG
#   inflating: rice_plant_lacks_nutrients/Phosphorus(P)/IMG_4108.JPG
#   inflating: rice_plant_lacks_nutrients/Phosphorus(P)/IMG_4109.JPG
#   inflating: rice_plant_lacks_nutrients/Phosphorus(P)/IMG_4110.JPG
#   inflating: rice_plant_lacks_nutrients/Phosphorus(P)/IMG_4111.JPG
#   inflating: rice_plant_lacks_nutrients/Phosphorus(P)/IMG_4112.JPG
#   inflating: rice_plant_lacks_nutrients/Phosphorus(P)/IMG_4113.JPG
#   inflating: rice_plant_lacks_nutrients/Phosphorus(P)/IMG_4114.JPG
#   inflating: rice_plant_lacks_nutrients/Phosphorus(P)/IMG_4115.JPG
#   inflating: rice_plant_lacks_nutrients/Phosphorus(P)/IMG_4116.JPG
#   inflating: rice_plant_lacks_nutrients/Phosphorus(P)/IMG_4117.JPG
#   inflating: rice_plant_lacks_nutrients/Phosphorus(P)/IMG_4118.JPG
#   inflating: rice_plant_lacks_nutrients/Phosphorus(P)/IMG_4120.JPG
#   inflating: rice_plant_lacks_nutrients/Phosphorus(P)/IMG_4121.JPG
#   inflating: rice_plant_lacks_nutrients/Phosphorus(P)/IMG_4122.JPG
#   inflating: rice_plant_lacks_nutrients/Phosphorus(P)/IMG_4123.JPG
#   inflating: rice_plant_lacks_nutrients/Phosphorus(P)/IMG_4124.JPG
#   inflating: rice_plant_lacks_nutrients/Phosphorus(P)/IMG_4125.JPG
#   inflating: rice_plant_lacks_nutrients/Phosphorus(P)/IMG_4126.JPG
#   inflating: rice_plant_lacks_nutrients/Phosphorus(P)/IMG_4127.JPG
#   inflating: rice_plant_lacks_nutrients/Phosphorus(P)/IMG_4128.JPG
#   inflating: rice_plant_lacks_nutrients/Phosphorus(P)/IMG_4129.JPG
#   inflating: rice_plant_lacks_nutrients/Phosphorus(P)/IMG_4130.JPG
#   inflating: rice_plant_lacks_nutrients/Phosphorus(P)/IMG_4131.JPG
#   inflating: rice_plant_lacks_nutrients/Phosphorus(P)/IMG_4132.JPG
#   inflating: rice_plant_lacks_nutrients/Phosphorus(P)/IMG_4133.JPG
#   inflating: rice_plant_lacks_nutrients/Phosphorus(P)/IMG_4134.JPG
#   inflating: rice_plant_lacks_nutrients/Phosphorus(P)/IMG_4135.JPG
#   inflating: rice_plant_lacks_nutrients/Phosphorus(P)/IMG_4136.JPG
#   inflating: rice_plant_lacks_nutrients/Phosphorus(P)/IMG_4254-1.JPG
#   inflating: rice_plant_lacks_nutrients/Phosphorus(P)/IMG_4255-2.JPG
#   inflating: rice_plant_lacks_nutrients/Phosphorus(P)/IMG_4256-3.JPG
#   inflating: rice_plant_lacks_nutrients/Phosphorus(P)/IMG_4257-4.JPG
#   inflating: rice_plant_lacks_nutrients/Phosphorus(P)/IMG_4258-5.JPG
#   inflating: rice_plant_lacks_nutrients/Phosphorus(P)/IMG_4259.JPG
#   inflating: rice_plant_lacks_nutrients/Phosphorus(P)/IMG_4260.JPG
#   inflating: rice_plant_lacks_nutrients/Phosphorus(P)/IMG_4261.JPG
#   inflating: rice_plant_lacks_nutrients/Phosphorus(P)/IMG_4262.JPG
#   inflating: rice_plant_lacks_nutrients/Phosphorus(P)/IMG_4263-6.JPG
#   inflating: rice_plant_lacks_nutrients/Phosphorus(P)/IMG_4263.JPG
#   inflating: rice_plant_lacks_nutrients/Phosphorus(P)/IMG_4264.JPG
#   inflating: rice_plant_lacks_nutrients/Phosphorus(P)/IMG_4265-7.JPG
#   inflating: rice_plant_lacks_nutrients/Phosphorus(P)/IMG_4265.JPG
#   inflating: rice_plant_lacks_nutrients/Phosphorus(P)/IMG_4266.JPG
#   inflating: rice_plant_lacks_nutrients/Phosphorus(P)/IMG_4267.JPG
#   inflating: rice_plant_lacks_nutrients/Phosphorus(P)/IMG_4268.JPG
#   inflating: rice_plant_lacks_nutrients/Phosphorus(P)/IMG_4269.JPG
#   inflating: rice_plant_lacks_nutrients/Phosphorus(P)/IMG_4270.JPG
#   inflating: rice_plant_lacks_nutrients/Phosphorus(P)/IMG_4271.JPG
#   inflating: rice_plant_lacks_nutrients/Phosphorus(P)/IMG_4272-8.JPG
#   inflating: rice_plant_lacks_nutrients/Phosphorus(P)/IMG_4272.JPG
#   inflating: rice_plant_lacks_nutrients/Phosphorus(P)/IMG_4273.JPG
#   inflating: rice_plant_lacks_nutrients/Phosphorus(P)/IMG_4274-9.JPG
#   inflating: rice_plant_lacks_nutrients/Phosphorus(P)/IMG_4274.JPG
#   inflating: rice_plant_lacks_nutrients/Phosphorus(P)/IMG_4275-10.JPG
#   inflating: rice_plant_lacks_nutrients/Phosphorus(P)/IMG_4275.JPG
#   inflating: rice_plant_lacks_nutrients/Phosphorus(P)/IMG_4276-11.JPG
#   inflating: rice_plant_lacks_nutrients/Phosphorus(P)/IMG_4276.JPG
#   inflating: rice_plant_lacks_nutrients/Phosphorus(P)/IMG_4277-12.JPG
#   inflating: rice_plant_lacks_nutrients/Phosphorus(P)/IMG_4277.JPG
#   inflating: rice_plant_lacks_nutrients/Phosphorus(P)/IMG_4278-13.JPG
#   inflating: rice_plant_lacks_nutrients/Phosphorus(P)/IMG_4278.JPG
#   inflating: rice_plant_lacks_nutrients/Phosphorus(P)/IMG_4279-14.JPG
#   inflating: rice_plant_lacks_nutrients/Phosphorus(P)/IMG_4279.JPG
#   inflating: rice_plant_lacks_nutrients/Phosphorus(P)/IMG_4280-15.JPG
#   inflating: rice_plant_lacks_nutrients/Phosphorus(P)/IMG_4280.JPG
#   inflating: rice_plant_lacks_nutrients/Phosphorus(P)/IMG_4281-16.JPG
#   inflating: rice_plant_lacks_nutrients/Phosphorus(P)/IMG_4281.JPG
#   inflating: rice_plant_lacks_nutrients/Phosphorus(P)/IMG_4282-17.JPG
#   inflating: rice_plant_lacks_nutrients/Phosphorus(P)/IMG_4282.JPG
#   inflating: rice_plant_lacks_nutrients/Phosphorus(P)/IMG_4283-18.JPG
#   inflating: rice_plant_lacks_nutrients/Phosphorus(P)/IMG_4283.JPG
#   inflating: rice_plant_lacks_nutrients/Phosphorus(P)/IMG_4284-19.JPG
#   inflating: rice_plant_lacks_nutrients/Phosphorus(P)/IMG_4284.JPG
#   inflating: rice_plant_lacks_nutrients/Phosphorus(P)/IMG_4285-20.JPG
#   inflating: rice_plant_lacks_nutrients/Phosphorus(P)/IMG_4285.JPG
#   inflating: rice_plant_lacks_nutrients/Phosphorus(P)/IMG_4286-21.JPG
#   inflating: rice_plant_lacks_nutrients/Phosphorus(P)/IMG_4286.JPG
#   inflating: rice_plant_lacks_nutrients/Phosphorus(P)/IMG_4287-22.JPG
#   inflating: rice_plant_lacks_nutrients/Phosphorus(P)/IMG_4287.JPG
#   inflating: rice_plant_lacks_nutrients/Phosphorus(P)/IMG_4288-23.JPG
#   inflating: rice_plant_lacks_nutrients/Phosphorus(P)/IMG_4288.JPG
#   inflating: rice_plant_lacks_nutrients/Phosphorus(P)/IMG_4289-24.JPG
#   inflating: rice_plant_lacks_nutrients/Phosphorus(P)/IMG_4289.JPG
#   inflating: rice_plant_lacks_nutrients/Phosphorus(P)/IMG_4290.JPG
#   inflating: rice_plant_lacks_nutrients/Phosphorus(P)/IMG_4291.JPG
#   inflating: rice_plant_lacks_nutrients/Phosphorus(P)/IMG_4292.JPG
#   inflating: rice_plant_lacks_nutrients/Phosphorus(P)/IMG_4293.JPG
#   inflating: rice_plant_lacks_nutrients/Phosphorus(P)/IMG_4294.JPG
#   inflating: rice_plant_lacks_nutrients/Phosphorus(P)/IMG_4295.JPG
#   inflating: rice_plant_lacks_nutrients/Phosphorus(P)/IMG_4296.JPG
#   inflating: rice_plant_lacks_nutrients/Phosphorus(P)/IMG_4297.JPG
#   inflating: rice_plant_lacks_nutrients/Phosphorus(P)/IMG_4298.JPG
#   inflating: rice_plant_lacks_nutrients/Phosphorus(P)/IMG_4299-25.JPG
#   inflating: rice_plant_lacks_nutrients/Phosphorus(P)/IMG_4299.JPG
#   inflating: rice_plant_lacks_nutrients/Phosphorus(P)/IMG_4300-26.JPG
#   inflating: rice_plant_lacks_nutrients/Phosphorus(P)/IMG_4300.JPG
#   inflating: rice_plant_lacks_nutrients/Phosphorus(P)/IMG_4301-27-2.JPG
#   inflating: rice_plant_lacks_nutrients/Phosphorus(P)/IMG_4301-27.JPG
#   inflating: rice_plant_lacks_nutrients/Phosphorus(P)/IMG_4301.JPG
#   inflating: rice_plant_lacks_nutrients/Phosphorus(P)/IMG_4302-28.JPG
#   inflating: rice_plant_lacks_nutrients/Phosphorus(P)/IMG_4302.JPG
#   inflating: rice_plant_lacks_nutrients/Phosphorus(P)/IMG_4303-29.JPG
#   inflating: rice_plant_lacks_nutrients/Phosphorus(P)/IMG_4303.JPG
#   inflating: rice_plant_lacks_nutrients/Phosphorus(P)/IMG_4304-30.JPG
#   inflating: rice_plant_lacks_nutrients/Phosphorus(P)/IMG_4304.JPG
#   inflating: rice_plant_lacks_nutrients/Phosphorus(P)/IMG_4305-31.JPG
#   inflating: rice_plant_lacks_nutrients/Phosphorus(P)/IMG_4305.JPG
#   inflating: rice_plant_lacks_nutrients/Phosphorus(P)/IMG_4306.JPG
#   inflating: rice_plant_lacks_nutrients/Phosphorus(P)/IMG_4307.JPG
#   inflating: rice_plant_lacks_nutrients/Phosphorus(P)/IMG_4308-32.JPG
#   inflating: rice_plant_lacks_nutrients/Phosphorus(P)/IMG_4308.JPG
#   inflating: rice_plant_lacks_nutrients/Phosphorus(P)/IMG_4309-33.JPG
#   inflating: rice_plant_lacks_nutrients/Phosphorus(P)/IMG_4309.JPG
#   inflating: rice_plant_lacks_nutrients/Phosphorus(P)/IMG_4310-34.JPG
#   inflating: rice_plant_lacks_nutrients/Phosphorus(P)/IMG_4310.JPG
#   inflating: rice_plant_lacks_nutrients/Phosphorus(P)/IMG_4312.JPG
#   inflating: rice_plant_lacks_nutrients/Phosphorus(P)/IMG_4313.JPG
#   inflating: rice_plant_lacks_nutrients/Phosphorus(P)/IMG_4314.JPG
#   inflating: rice_plant_lacks_nutrients/Phosphorus(P)/IMG_4315.JPG
#   inflating: rice_plant_lacks_nutrients/Phosphorus(P)/IMG_4316.JPG
#   inflating: rice_plant_lacks_nutrients/Phosphorus(P)/IMG_4317.JPG
#   inflating: rice_plant_lacks_nutrients/Phosphorus(P)/IMG_4318.JPG
#   inflating: rice_plant_lacks_nutrients/Phosphorus(P)/IMG_4319.JPG
#   inflating: rice_plant_lacks_nutrients/Phosphorus(P)/IMG_4320-35.JPG
#   inflating: rice_plant_lacks_nutrients/Phosphorus(P)/IMG_4320.JPG
#   inflating: rice_plant_lacks_nutrients/Phosphorus(P)/IMG_4321.JPG
#   inflating: rice_plant_lacks_nutrients/Phosphorus(P)/IMG_4322.JPG
#   inflating: rice_plant_lacks_nutrients/Phosphorus(P)/IMG_4323-36.JPG
#   inflating: rice_plant_lacks_nutrients/Phosphorus(P)/IMG_4323.JPG
#   inflating: rice_plant_lacks_nutrients/Phosphorus(P)/IMG_4324.JPG
#   inflating: rice_plant_lacks_nutrients/Phosphorus(P)/IMG_4325.JPG
#   inflating: rice_plant_lacks_nutrients/Phosphorus(P)/IMG_4326.JPG
#   inflating: rice_plant_lacks_nutrients/Phosphorus(P)/IMG_4327.JPG
#   inflating: rice_plant_lacks_nutrients/Phosphorus(P)/IMG_4328.JPG
#   inflating: rice_plant_lacks_nutrients/Phosphorus(P)/IMG_4329.JPG
#   inflating: rice_plant_lacks_nutrients/Phosphorus(P)/IMG_4330.JPG
#   inflating: rice_plant_lacks_nutrients/Phosphorus(P)/IMG_4331.JPG
#   inflating: rice_plant_lacks_nutrients/Phosphorus(P)/IMG_4332.JPG
#   inflating: rice_plant_lacks_nutrients/Phosphorus(P)/IMG_4333.JPG
#   inflating: rice_plant_lacks_nutrients/Phosphorus(P)/IMG_4334.JPG
#   inflating: rice_plant_lacks_nutrients/Phosphorus(P)/IMG_4335-37.JPG
#   inflating: rice_plant_lacks_nutrients/Phosphorus(P)/IMG_4335.JPG
#   inflating: rice_plant_lacks_nutrients/Phosphorus(P)/IMG_4336-38.JPG
#   inflating: rice_plant_lacks_nutrients/Phosphorus(P)/IMG_4336.JPG
#   inflating: rice_plant_lacks_nutrients/Phosphorus(P)/IMG_4337.JPG
#   inflating: rice_plant_lacks_nutrients/Phosphorus(P)/IMG_4338.JPG
#   inflating: rice_plant_lacks_nutrients/Phosphorus(P)/IMG_4339.JPG
#   inflating: rice_plant_lacks_nutrients/Phosphorus(P)/IMG_4340-39.JPG
#   inflating: rice_plant_lacks_nutrients/Phosphorus(P)/IMG_4340.JPG
#   inflating: rice_plant_lacks_nutrients/Phosphorus(P)/IMG_4342.JPG
#   inflating: rice_plant_lacks_nutrients/Phosphorus(P)/IMG_4343.JPG
#   inflating: rice_plant_lacks_nutrients/Phosphorus(P)/IMG_4344.JPG
#   inflating: rice_plant_lacks_nutrients/Phosphorus(P)/IMG_4345.JPG
#   inflating: rice_plant_lacks_nutrients/Phosphorus(P)/IMG_4346.JPG
#   inflating: rice_plant_lacks_nutrients/Phosphorus(P)/IMG_4347.JPG
#   inflating: rice_plant_lacks_nutrients/Phosphorus(P)/IMG_4348.JPG
#   inflating: rice_plant_lacks_nutrients/Phosphorus(P)/IMG_4349.JPG
#   inflating: rice_plant_lacks_nutrients/Phosphorus(P)/IMG_4350.JPG
#   inflating: rice_plant_lacks_nutrients/Phosphorus(P)/IMG_4351.JPG
#   inflating: rice_plant_lacks_nutrients/Phosphorus(P)/IMG_4352.JPG
#   inflating: rice_plant_lacks_nutrients/Phosphorus(P)/IMG_4354.JPG
#   inflating: rice_plant_lacks_nutrients/Phosphorus(P)/IMG_4355.JPG
#   inflating: rice_plant_lacks_nutrients/Phosphorus(P)/IMG_4362.JPG
#   inflating: rice_plant_lacks_nutrients/Phosphorus(P)/IMG_4573.JPG
#   inflating: rice_plant_lacks_nutrients/Phosphorus(P)/IMG_4577.JPG
#   inflating: rice_plant_lacks_nutrients/Phosphorus(P)/IMG_4578.JPG
#   inflating: rice_plant_lacks_nutrients/Phosphorus(P)/IMG_4579.JPG
#   inflating: rice_plant_lacks_nutrients/Phosphorus(P)/IMG_4580.JPG
#   inflating: rice_plant_lacks_nutrients/Phosphorus(P)/IMG_4581.JPG
#   inflating: rice_plant_lacks_nutrients/Phosphorus(P)/IMG_4582.JPG
#   inflating: rice_plant_lacks_nutrients/Phosphorus(P)/IMG_4583.JPG
#   inflating: rice_plant_lacks_nutrients/Phosphorus(P)/IMG_4584.JPG
#   inflating: rice_plant_lacks_nutrients/Phosphorus(P)/IMG_4585.JPG
#   inflating: rice_plant_lacks_nutrients/Phosphorus(P)/IMG_4586.JPG
#   inflating: rice_plant_lacks_nutrients/Phosphorus(P)/IMG_4588.JPG
#   inflating: rice_plant_lacks_nutrients/Phosphorus(P)/IMG_4589.JPG
# ...
#   inflating: rice_plant_lacks_nutrients/Potassium(K)/untitled-243.JPG
#   inflating: rice_plant_lacks_nutrients/Potassium(K)/untitled-244.JPG
#   inflating: rice_plant_lacks_nutrients/Potassium(K)/untitled-245.JPG
#   inflating: rice_plant_lacks_nutrients/Potassium(K)/untitled-246.JPG
#   inflating: rice_plant_lacks_nutrients/Potassium(K)/untitled-247.JPG
#   inflating: rice_plant_lacks_nutrients/Potassium(K)/untitled-248.JPG
#   inflating: rice_plant_lacks_nutrients/Potassium(K)/untitled-249.JPG
#   inflating: rice_plant_lacks_nutrients/Potassium(K)/untitled-25.JPG
#   inflating: rice_plant_lacks_nutrients/Potassium(K)/untitled-250.JPG
#   inflating: rice_plant_lacks_nutrients/Potassium(K)/untitled-251.JPG
#   inflating: rice_plant_lacks_nutrients/Potassium(K)/untitled-252.JPG
#   inflating: rice_plant_lacks_nutrients/Potassium(K)/untitled-253.JPG
#   inflating: rice_plant_lacks_nutrients/Potassium(K)/untitled-254.JPG
#   inflating: rice_plant_lacks_nutrients/Potassium(K)/untitled-255.JPG
#   inflating: rice_plant_lacks_nutrients/Potassium(K)/untitled-256.JPG
#   inflating: rice_plant_lacks_nutrients/Potassium(K)/untitled-258.JPG
#   inflating: rice_plant_lacks_nutrients/Potassium(K)/untitled-259.JPG
#   inflating: rice_plant_lacks_nutrients/Potassium(K)/untitled-26.JPG
#   inflating: rice_plant_lacks_nutrients/Potassium(K)/untitled-260.JPG
#   inflating: rice_plant_lacks_nutrients/Potassium(K)/untitled-261.JPG
#   inflating: rice_plant_lacks_nutrients/Potassium(K)/untitled-262.JPG
#   inflating: rice_plant_lacks_nutrients/Potassium(K)/untitled-263.JPG
#   inflating: rice_plant_lacks_nutrients/Potassium(K)/untitled-264.JPG
#   inflating: rice_plant_lacks_nutrients/Potassium(K)/untitled-265.JPG
#   inflating: rice_plant_lacks_nutrients/Potassium(K)/untitled-266.JPG
#   inflating: rice_plant_lacks_nutrients/Potassium(K)/untitled-267.JPG
#   inflating: rice_plant_lacks_nutrients/Potassium(K)/untitled-268.JPG
#   inflating: rice_plant_lacks_nutrients/Potassium(K)/untitled-269.JPG
#   inflating: rice_plant_lacks_nutrients/Potassium(K)/untitled-27.JPG
#   inflating: rice_plant_lacks_nutrients/Potassium(K)/untitled-270.JPG
#   inflating: rice_plant_lacks_nutrients/Potassium(K)/untitled-271.JPG
#   inflating: rice_plant_lacks_nutrients/Potassium(K)/untitled-272.JPG
#   inflating: rice_plant_lacks_nutrients/Potassium(K)/untitled-273.JPG
#   inflating: rice_plant_lacks_nutrients/Potassium(K)/untitled-274.JPG
#   inflating: rice_plant_lacks_nutrients/Potassium(K)/untitled-275.JPG
#   inflating: rice_plant_lacks_nutrients/Potassium(K)/untitled-276.JPG
#   inflating: rice_plant_lacks_nutrients/Potassium(K)/untitled-277.JPG
#   inflating: rice_plant_lacks_nutrients/Potassium(K)/untitled-278.JPG
#   inflating: rice_plant_lacks_nutrients/Potassium(K)/untitled-279.JPG
#   inflating: rice_plant_lacks_nutrients/Potassium(K)/untitled-28.JPG
#   inflating: rice_plant_lacks_nutrients/Potassium(K)/untitled-280.JPG
#   inflating: rice_plant_lacks_nutrients/Potassium(K)/untitled-281.JPG
#   inflating: rice_plant_lacks_nutrients/Potassium(K)/untitled-282.JPG
#   inflating: rice_plant_lacks_nutrients/Potassium(K)/untitled-283.JPG
#   inflating: rice_plant_lacks_nutrients/Potassium(K)/untitled-284.JPG
#   inflating: rice_plant_lacks_nutrients/Potassium(K)/untitled-285.JPG
#   inflating: rice_plant_lacks_nutrients/Potassium(K)/untitled-286.JPG
#   inflating: rice_plant_lacks_nutrients/Potassium(K)/untitled-287.JPG
#   inflating: rice_plant_lacks_nutrients/Potassium(K)/untitled-288.JPG
#   inflating: rice_plant_lacks_nutrients/Potassium(K)/untitled-289.JPG
#   inflating: rice_plant_lacks_nutrients/Potassium(K)/untitled-29.JPG
#   inflating: rice_plant_lacks_nutrients/Potassium(K)/untitled-290.JPG
#   inflating: rice_plant_lacks_nutrients/Potassium(K)/untitled-291.JPG
#   inflating: rice_plant_lacks_nutrients/Potassium(K)/untitled-292.JPG
#   inflating: rice_plant_lacks_nutrients/Potassium(K)/untitled-293.JPG
#   inflating: rice_plant_lacks_nutrients/Potassium(K)/untitled-294.JPG
#   inflating: rice_plant_lacks_nutrients/Potassium(K)/untitled-295.JPG
#   inflating: rice_plant_lacks_nutrients/Potassium(K)/untitled-296.JPG
#   inflating: rice_plant_lacks_nutrients/Potassium(K)/untitled-297.JPG
#   inflating: rice_plant_lacks_nutrients/Potassium(K)/untitled-298.JPG
#   inflating: rice_plant_lacks_nutrients/Potassium(K)/untitled-299.JPG
#   inflating: rice_plant_lacks_nutrients/Potassium(K)/untitled-3.JPG
#   inflating: rice_plant_lacks_nutrients/Potassium(K)/untitled-30.JPG
#   inflating: rice_plant_lacks_nutrients/Potassium(K)/untitled-300.JPG
#   inflating: rice_plant_lacks_nutrients/Potassium(K)/untitled-301.JPG
#   inflating: rice_plant_lacks_nutrients/Potassium(K)/untitled-302.JPG
#   inflating: rice_plant_lacks_nutrients/Potassium(K)/untitled-303.JPG
#   inflating: rice_plant_lacks_nutrients/Potassium(K)/untitled-304.JPG
#   inflating: rice_plant_lacks_nutrients/Potassium(K)/untitled-305.JPG
#   inflating: rice_plant_lacks_nutrients/Potassium(K)/untitled-306.JPG
#   inflating: rice_plant_lacks_nutrients/Potassium(K)/untitled-307.JPG
#   inflating: rice_plant_lacks_nutrients/Potassium(K)/untitled-308.JPG
#   inflating: rice_plant_lacks_nutrients/Potassium(K)/untitled-309.JPG
#   inflating: rice_plant_lacks_nutrients/Potassium(K)/untitled-31.JPG
#   inflating: rice_plant_lacks_nutrients/Potassium(K)/untitled-310.JPG
#   inflating: rice_plant_lacks_nutrients/Potassium(K)/untitled-311.JPG
#   inflating: rice_plant_lacks_nutrients/Potassium(K)/untitled-312.JPG
#   inflating: rice_plant_lacks_nutrients/Potassium(K)/untitled-313.JPG
#   inflating: rice_plant_lacks_nutrients/Potassium(K)/untitled-314.JPG
#   inflating: rice_plant_lacks_nutrients/Potassium(K)/untitled-315.JPG
#   inflating: rice_plant_lacks_nutrients/Potassium(K)/untitled-316.JPG
#   inflating: rice_plant_lacks_nutrients/Potassium(K)/untitled-317.JPG
#   inflating: rice_plant_lacks_nutrients/Potassium(K)/untitled-318.JPG
#   inflating: rice_plant_lacks_nutrients/Potassium(K)/untitled-319.JPG
#   inflating: rice_plant_lacks_nutrients/Potassium(K)/untitled-32.JPG
#   inflating: rice_plant_lacks_nutrients/Potassium(K)/untitled-320.JPG
#   inflating: rice_plant_lacks_nutrients/Potassium(K)/untitled-321.JPG
#   inflating: rice_plant_lacks_nutrients/Potassium(K)/untitled-322.JPG
#   inflating: rice_plant_lacks_nutrients/Potassium(K)/untitled-323.JPG
#   inflating: rice_plant_lacks_nutrients/Potassium(K)/untitled-324.JPG
#   inflating: rice_plant_lacks_nutrients/Potassium(K)/untitled-325.JPG
#   inflating: rice_plant_lacks_nutrients/Potassium(K)/untitled-326.JPG
#   inflating: rice_plant_lacks_nutrients/Potassium(K)/untitled-327.JPG
#   inflating: rice_plant_lacks_nutrients/Potassium(K)/untitled-328.JPG
#   inflating: rice_plant_lacks_nutrients/Potassium(K)/untitled-329.JPG
#   inflating: rice_plant_lacks_nutrients/Potassium(K)/untitled-33.JPG
#   inflating: rice_plant_lacks_nutrients/Potassium(K)/untitled-330.JPG
#   inflating: rice_plant_lacks_nutrients/Potassium(K)/untitled-331.JPG
#   inflating: rice_plant_lacks_nutrients/Potassium(K)/untitled-332.JPG
#   inflating: rice_plant_lacks_nutrients/Potassium(K)/untitled-333.JPG
#   inflating: rice_plant_lacks_nutrients/Potassium(K)/untitled-334.JPG
#   inflating: rice_plant_lacks_nutrients/Potassium(K)/untitled-335.JPG
#   inflating: rice_plant_lacks_nutrients/Potassium(K)/untitled-336.JPG
#   inflating: rice_plant_lacks_nutrients/Potassium(K)/untitled-337.JPG
#   inflating: rice_plant_lacks_nutrients/Potassium(K)/untitled-338.JPG
#   inflating: rice_plant_lacks_nutrients/Potassium(K)/untitled-339.JPG
#   inflating: rice_plant_lacks_nutrients/Potassium(K)/untitled-34.JPG
#   inflating: rice_plant_lacks_nutrients/Potassium(K)/untitled-340.JPG
#   inflating: rice_plant_lacks_nutrients/Potassium(K)/untitled-341.JPG
#   inflating: rice_plant_lacks_nutrients/Potassium(K)/untitled-342.JPG
#   inflating: rice_plant_lacks_nutrients/Potassium(K)/untitled-343.JPG
#   inflating: rice_plant_lacks_nutrients/Potassium(K)/untitled-344.JPG
#   inflating: rice_plant_lacks_nutrients/Potassium(K)/untitled-345.JPG
#   inflating: rice_plant_lacks_nutrients/Potassium(K)/untitled-346.JPG
#   inflating: rice_plant_lacks_nutrients/Potassium(K)/untitled-347.JPG
#   inflating: rice_plant_lacks_nutrients/Potassium(K)/untitled-348.JPG
#   inflating: rice_plant_lacks_nutrients/Potassium(K)/untitled-349.JPG
#   inflating: rice_plant_lacks_nutrients/Potassium(K)/untitled-35.JPG
#   inflating: rice_plant_lacks_nutrients/Potassium(K)/untitled-350.JPG
#   inflating: rice_plant_lacks_nutrients/Potassium(K)/untitled-351.JPG
#   inflating: rice_plant_lacks_nutrients/Potassium(K)/untitled-352.JPG
#   inflating: rice_plant_lacks_nutrients/Potassium(K)/untitled-353.JPG
#   inflating: rice_plant_lacks_nutrients/Potassium(K)/untitled-354.JPG
#   inflating: rice_plant_lacks_nutrients/Potassium(K)/untitled-355.JPG
#   inflating: rice_plant_lacks_nutrients/Potassium(K)/untitled-356.JPG
#   inflating: rice_plant_lacks_nutrients/Potassium(K)/untitled-357.JPG
#   inflating: rice_plant_lacks_nutrients/Potassium(K)/untitled-358.JPG
#   inflating: rice_plant_lacks_nutrients/Potassium(K)/untitled-359.JPG
#   inflating: rice_plant_lacks_nutrients/Potassium(K)/untitled-36.JPG
#   inflating: rice_plant_lacks_nutrients/Potassium(K)/untitled-360.JPG
#   inflating: rice_plant_lacks_nutrients/Potassium(K)/untitled-361.JPG
#   inflating: rice_plant_lacks_nutrients/Potassium(K)/untitled-362.JPG
#   inflating: rice_plant_lacks_nutrients/Potassium(K)/untitled-363.JPG
#   inflating: rice_plant_lacks_nutrients/Potassium(K)/untitled-364.JPG
#   inflating: rice_plant_lacks_nutrients/Potassium(K)/untitled-365.JPG
#   inflating: rice_plant_lacks_nutrients/Potassium(K)/untitled-366.JPG
#   inflating: rice_plant_lacks_nutrients/Potassium(K)/untitled-367.JPG
#   inflating: rice_plant_lacks_nutrients/Potassium(K)/untitled-368.JPG
#   inflating: rice_plant_lacks_nutrients/Potassium(K)/untitled-369.JPG
#   inflating: rice_plant_lacks_nutrients/Potassium(K)/untitled-37.JPG
#   inflating: rice_plant_lacks_nutrients/Potassium(K)/untitled-370.JPG
#   inflating: rice_plant_lacks_nutrients/Potassium(K)/untitled-371.JPG
#   inflating: rice_plant_lacks_nutrients/Potassium(K)/untitled-372.JPG
#   inflating: rice_plant_lacks_nutrients/Potassium(K)/untitled-373.JPG
#   inflating: rice_plant_lacks_nutrients/Potassium(K)/untitled-374.JPG
#   inflating: rice_plant_lacks_nutrients/Potassium(K)/untitled-375.JPG
#   inflating: rice_plant_lacks_nutrients/Potassium(K)/untitled-376.JPG
#   inflating: rice_plant_lacks_nutrients/Potassium(K)/untitled-377.JPG
#   inflating: rice_plant_lacks_nutrients/Potassium(K)/untitled-378.JPG
#   inflating: rice_plant_lacks_nutrients/Potassium(K)/untitled-379.JPG
#   inflating: rice_plant_lacks_nutrients/Potassium(K)/untitled-38.JPG
#   inflating: rice_plant_lacks_nutrients/Potassium(K)/untitled-380.JPG
#   inflating: rice_plant_lacks_nutrients/Potassium(K)/untitled-381.JPG
#   inflating: rice_plant_lacks_nutrients/Potassium(K)/untitled-382.JPG
#   inflating: rice_plant_lacks_nutrients/Potassium(K)/untitled-383.JPG
#   inflating: rice_plant_lacks_nutrients/Potassium(K)/untitled-384.JPG
#   inflating: rice_plant_lacks_nutrients/Potassium(K)/untitled-39.JPG
#   inflating: rice_plant_lacks_nutrients/Potassium(K)/untitled-4.JPG
#   inflating: rice_plant_lacks_nutrients/Potassium(K)/untitled-40.JPG
#   inflating: rice_plant_lacks_nutrients/Potassium(K)/untitled-41.JPG
#   inflating: rice_plant_lacks_nutrients/Potassium(K)/untitled-42.JPG
#   inflating: rice_plant_lacks_nutrients/Potassium(K)/untitled-43.JPG
#   inflating: rice_plant_lacks_nutrients/Potassium(K)/untitled-44.JPG
#   inflating: rice_plant_lacks_nutrients/Potassium(K)/untitled-45.JPG
#   inflating: rice_plant_lacks_nutrients/Potassium(K)/untitled-46.JPG
#   inflating: rice_plant_lacks_nutrients/Potassium(K)/untitled-47.JPG
#   inflating: rice_plant_lacks_nutrients/Potassium(K)/untitled-48.JPG
#   inflating: rice_plant_lacks_nutrients/Potassium(K)/untitled-49.JPG
#   inflating: rice_plant_lacks_nutrients/Potassium(K)/untitled-5.JPG
#   inflating: rice_plant_lacks_nutrients/Potassium(K)/untitled-50.JPG
#   inflating: rice_plant_lacks_nutrients/Potassium(K)/untitled-51.JPG
#   inflating: rice_plant_lacks_nutrients/Potassium(K)/untitled-52.JPG
#   inflating: rice_plant_lacks_nutrients/Potassium(K)/untitled-53.JPG
#   inflating: rice_plant_lacks_nutrients/Potassium(K)/untitled-54.JPG
#   inflating: rice_plant_lacks_nutrients/Potassium(K)/untitled-55.JPG
#   inflating: rice_plant_lacks_nutrients/Potassium(K)/untitled-56.JPG
#   inflating: rice_plant_lacks_nutrients/Potassium(K)/untitled-57.JPG
#   inflating: rice_plant_lacks_nutrients/Potassium(K)/untitled-58.JPG
#   inflating: rice_plant_lacks_nutrients/Potassium(K)/untitled-59.JPG
#   inflating: rice_plant_lacks_nutrients/Potassium(K)/untitled-6.JPG
#   inflating: rice_plant_lacks_nutrients/Potassium(K)/untitled-60.JPG
#   inflating: rice_plant_lacks_nutrients/Potassium(K)/untitled-61.JPG
#   inflating: rice_plant_lacks_nutrients/Potassium(K)/untitled-62.JPG
#   inflating: rice_plant_lacks_nutrients/Potassium(K)/untitled-63.JPG
#   inflating: rice_plant_lacks_nutrients/Potassium(K)/untitled-64.JPG
#   inflating: rice_plant_lacks_nutrients/Potassium(K)/untitled-65.JPG
#   inflating: rice_plant_lacks_nutrients/Potassium(K)/untitled-66.JPG
#   inflating: rice_plant_lacks_nutrients/Potassium(K)/untitled-67.JPG
#   inflating: rice_plant_lacks_nutrients/Potassium(K)/untitled-68.JPG
#   inflating: rice_plant_lacks_nutrients/Potassium(K)/untitled-69.JPG
#   inflating: rice_plant_lacks_nutrients/Potassium(K)/untitled-7.JPG
#   inflating: rice_plant_lacks_nutrients/Potassium(K)/untitled-70.JPG
#   inflating: rice_plant_lacks_nutrients/Potassium(K)/untitled-71.JPG
#   inflating: rice_plant_lacks_nutrients/Potassium(K)/untitled-72.JPG
#   inflating: rice_plant_lacks_nutrients/Potassium(K)/untitled-73.JPG
#   inflating: rice_plant_lacks_nutrients/Potassium(K)/untitled-74.JPG
#   inflating: rice_plant_lacks_nutrients/Potassium(K)/untitled-75.JPG
#   inflating: rice_plant_lacks_nutrients/Potassium(K)/untitled-76.JPG
#   inflating: rice_plant_lacks_nutrients/Potassium(K)/untitled-77.JPG
#   inflating: rice_plant_lacks_nutrients/Potassium(K)/untitled-78.JPG
#   inflating: rice_plant_lacks_nutrients/Potassium(K)/untitled-79.JPG
#   inflating: rice_plant_lacks_nutrients/Potassium(K)/untitled-8.JPG
#   inflating: rice_plant_lacks_nutrients/Potassium(K)/untitled-80.JPG
#   inflating: rice_plant_lacks_nutrients/Potassium(K)/untitled-81.JPG
#   inflating: rice_plant_lacks_nutrients/Potassium(K)/untitled-82.JPG
#   inflating: rice_plant_lacks_nutrients/Potassium(K)/untitled-83.JPG
#   inflating: rice_plant_lacks_nutrients/Potassium(K)/untitled-84.JPG
#   inflating: rice_plant_lacks_nutrients/Potassium(K)/untitled-85.JPG
#   inflating: rice_plant_lacks_nutrients/Potassium(K)/untitled-86.JPG
#   inflating: rice_plant_lacks_nutrients/Potassium(K)/untitled-87.JPG
#   inflating: rice_plant_lacks_nutrients/Potassium(K)/untitled-88.JPG
#   inflating: rice_plant_lacks_nutrients/Potassium(K)/untitled-89.JPG
#   inflating: rice_plant_lacks_nutrients/Potassium(K)/untitled-9.JPG
#   inflating: rice_plant_lacks_nutrients/Potassium(K)/untitled-90.JPG
#   inflating: rice_plant_lacks_nutrients/Potassium(K)/untitled-91.JPG
#   inflating: rice_plant_lacks_nutrients/Potassium(K)/untitled-92.JPG
#   inflating: rice_plant_lacks_nutrients/Potassium(K)/untitled-93.JPG
#   inflating: rice_plant_lacks_nutrients/Potassium(K)/untitled-94.JPG
#   inflating: rice_plant_lacks_nutrients/Potassium(K)/untitled-95.JPG
#   inflating: rice_plant_lacks_nutrients/Potassium(K)/untitled-96.JPG
#   inflating: rice_plant_lacks_nutrients/Potassium(K)/untitled-97.JPG
#   inflating: rice_plant_lacks_nutrients/Potassium(K)/untitled-98.JPG
#   inflating: rice_plant_lacks_nutrients/Potassium(K)/untitled-99.JPG

# %% [markdown]
# ## Data Preprocessing

# %%
# This Python 3 environment comes with many helpful analytics libraries installed
# It is defined by the kaggle/python Docker image: https://github.com/kaggle/docker-python
# For example, here's several helpful packages to load

# Input data files are available in the read-only "../input/" directory
# For example, running this (by clicking run or pressing Shift+Enter) will list all files under the input directory

#for dirname, _, filenames in os.walk('/kaggle/input'):
    #for filename in filenames:
        #print(os.path.join(dirname, filename))

# You can write up to 20GB to the current directory (/kaggle/working/) that gets preserved as output when you create a version using "Save & Run All" 
# You can also write temporary files to /kaggle/temp/, but they won't be saved outside of the current session

# %%
# Split with a ratio.
# To only split into training and validation set, set a tuple to `ratio`, i.e, `(.8, .2)`.
splitfolders.ratio("/content/rice_plant_lacks_nutrients", output="output",
    seed=1337, ratio=(.75, .2, .05), group_prefix=None, move=False) # default values
#splitfolders.fixed("/content/rice_plant_lacks_nutrients", output="output", seed=1337, fixed=(50, 50), oversample=True, group_prefix=None, move=False)
# Out:
# Copying files: 1156 files [00:04, 244.97 files/s]

# %% [markdown]
# ## Exploratory Data Analysis

# %%
# Folder location
data_dir = pathlib.Path('/content/output/train')
train_dir = '/content/output/train'
val_dir = '/content/output/val'
test_dir = '/content/output/test'

# %%
# Show classes
class_name = np.array(sorted([item.name for item in data_dir.glob("*")]))
print(class_name)
# Out:
# ['Nitrogen(N)' 'Phosphorus(P)' 'Potassium(K)']

# %%
# Show total data in folder
for dirpath, dirnames, filenames in os.walk('output'):
  print(f"{len(dirnames)} folder and {len(filenames)} images in {dirpath}")
# Out:
# 3 folder and 0 images in output
# 3 folder and 0 images in output/train
# 0 folder and 330 images in output/train/Nitrogen(N)
# 0 folder and 287 images in output/train/Potassium(K)
# 0 folder and 249 images in output/train/Phosphorus(P)
# 3 folder and 0 images in output/val
# 0 folder and 88 images in output/val/Nitrogen(N)
# 0 folder and 76 images in output/val/Potassium(K)
# 0 folder and 66 images in output/val/Phosphorus(P)
# 3 folder and 0 images in output/test
# 0 folder and 22 images in output/test/Nitrogen(N)
# 0 folder and 20 images in output/test/Potassium(K)
# 0 folder and 18 images in output/test/Phosphorus(P)

# %%
# Function for showing image sources
def view_random_image(target_dir, target_class):
    target_folder = target_dir + target_class
    random_image = random.sample(os.listdir(target_folder), 1)
    img = mpimg.imread(target_folder + "/" + random_image[0])
    plt.imshow(img)
    plt.title(target_class)
    plt.axis("off")
    
    print(f"Image Shape : {img.shape}")
    plt.show()

# %%
# Show image for classes 'Nitrogen(N)'
for i in range(1,6):
    img_n = view_random_image(target_dir='output/train/', target_class='Nitrogen(N)')
# Out:
# Image Shape : (3351, 299, 3)
# Image Shape : (251, 3886, 3)
# Image Shape : (2359, 242, 3)
# Image Shape : (3669, 265, 3)
# Image Shape : (3943, 305, 3)

# %%
# Show image for classes 'Phosphorus(P)'
for i in range(1,6):
    img_n = view_random_image(target_dir='output/train/', target_class='Phosphorus(P)')
# Out:
# Image Shape : (4030, 463, 3)
# Image Shape : (3131, 434, 3)
# Image Shape : (3949, 336, 3)
# Image Shape : (3903, 349, 3)
# Image Shape : (334, 2914, 3)

# %%
# Show image for classes 'Potassium(K)'
for i in range(1,6):
    img_n = view_random_image(target_dir='output/train/', target_class='Potassium(K)')
# Out:
# Image Shape : (3490, 380, 3)
# Image Shape : (4113, 372, 3)
# Image Shape : (3979, 516, 3)
# Image Shape : (3465, 569, 3)
# Image Shape : (3985, 363, 3)

# %% [markdown]
# ## Feature Engineering

# %%
# Sets the global random seed.
tf.random.set_seed(46)

# preprocess data
train_datagen = ImageDataGenerator(rescale=1/255.0,
                                   rotation_range=0.2,
                                   zoom_range=0.2,
                                   width_shift_range=0.2,
                                   height_shift_range=0.2,
                                   vertical_flip=True,
                                   horizontal_flip=True)
valid_datagen = ImageDataGenerator(rescale=1/255.0)
test_datagen = ImageDataGenerator(rescale=1/255.0)

# %% [markdown]
# ### Pipeline

# %%
# flow from directory using datagen (Pipeline)
train_data = train_datagen.flow_from_directory(train_dir,
                                               batch_size=16,
                                               target_size=(224, 224),
                                               class_mode='categorical',
                                               shuffle=True,
                                               seed=46)

valid_data = valid_datagen.flow_from_directory(val_dir,
                                               batch_size=16,
                                               target_size=(224, 224),
                                               class_mode='categorical',
                                               shuffle=False,
                                               seed=46)

test_data = test_datagen.flow_from_directory(test_dir,
                                               batch_size=16,
                                               target_size=(224, 224),
                                               class_mode='categorical',
                                               shuffle=False,
                                               seed=46)
# Out:
# Found 866 images belonging to 3 classes.
# Found 230 images belonging to 3 classes.
# Found 60 images belonging to 3 classes.

# %%
# Check class_indices
label_indices = train_data.class_indices
label_indices
# Out:
# {'Nitrogen(N)': 0, 'Phosphorus(P)': 1, 'Potassium(K)': 2}

# %%
# Set labels
train_y=train_data.classes
val_y=valid_data.classes
test_y=test_data.classes

# %%
# Check shapes of labels
print("train_y.shape: ", train_y.shape)
print("val_y.shape: ", val_y.shape)
print("test_y.shape: ", test_y.shape)
# Out:
# train_y.shape:  (866,)
# val_y.shape:  (230,)
# test_y.shape:  (60,)

# %% [markdown]
# ## Modelling

# %%
# Model Definition
base_model = tf.keras.applications.DenseNet121(input_shape=(224, 224, 3),
                                                        include_top=False,
                                                        weights='imagenet')
base_model.trainable = False
# Out:
# Downloading data from https://storage.googleapis.com/tensorflow/keras-applications/densenet/densenet121_weights_tf_dim_ordering_tf_kernels_notop.h5
# 29089792/29084464 [==============================] - 0s 0us/step
# 29097984/29084464 [==============================] - 0s 0us/step

# %%
# Model Preparation
global_average_layer = GlobalAveragePooling2D()
prediction_layer = Dense(3)
softmax = Activation('softmax')

inputs = Input(shape=(224, 224, 3))
x = base_model(inputs, training=False)
x = Dropout(0.25)(x)
x = global_average_layer(x)
outputs = prediction_layer(x)
outputs = softmax(outputs)

model = Model(inputs, outputs)

# %%
# Model Summary
model.summary()
# Out:
# Model: "model"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  input_2 (InputLayer)        [(None, 224, 224, 3)]     0
#
#  densenet121 (Functional)    (None, 7, 7, 1024)        7037504
#
#  dropout (Dropout)           (None, 7, 7, 1024)        0
#
#  global_average_pooling2d (G  (None, 1024)             0
#  lobalAveragePooling2D)
#
#  dense (Dense)               (None, 3)                 3075
#
#  activation (Activation)     (None, 3)                 0
#
# =================================================================
# Total params: 7,040,579
# Trainable params: 3,075
# Non-trainable params: 7,037,504
# _________________________________________________________________

# %%
# Plot of Model Summary
plot_model(model, show_shapes=True)

# %%
# compile model
model.compile(loss='categorical_crossentropy',
              optimizer=Adam(learning_rate=0.001),
              metrics=['accuracy'])

# train model
initial_epochs = 15
history = model.fit(train_data, epochs=initial_epochs, validation_data=valid_data)
# Out:
# Epoch 1/15
# 55/55 [==============================] - 73s 1s/step - loss: 1.0693 - accuracy: 0.4931 - val_loss: 0.7981 - val_accuracy: 0.6565
# Epoch 2/15
# 55/55 [==============================] - 52s 946ms/step - loss: 0.6738 - accuracy: 0.7494 - val_loss: 0.5520 - val_accuracy: 0.8043
# Epoch 3/15
# 55/55 [==============================] - 51s 928ms/step - loss: 0.5182 - accuracy: 0.8233 - val_loss: 0.4650 - val_accuracy: 0.8261
# Epoch 4/15
# 55/55 [==============================] - 51s 933ms/step - loss: 0.4413 - accuracy: 0.8614 - val_loss: 0.4129 - val_accuracy: 0.8652
# Epoch 5/15
# 55/55 [==============================] - 50s 907ms/step - loss: 0.3819 - accuracy: 0.8822 - val_loss: 0.3532 - val_accuracy: 0.8957
# Epoch 6/15
# 55/55 [==============================] - 50s 912ms/step - loss: 0.3370 - accuracy: 0.8915 - val_loss: 0.3231 - val_accuracy: 0.8913
# Epoch 7/15
# 55/55 [==============================] - 49s 898ms/step - loss: 0.2990 - accuracy: 0.8995 - val_loss: 0.3021 - val_accuracy: 0.8870
# Epoch 8/15
# 55/55 [==============================] - 49s 896ms/step - loss: 0.2974 - accuracy: 0.9042 - val_loss: 0.2892 - val_accuracy: 0.9087
# Epoch 9/15
# 55/55 [==============================] - 49s 900ms/step - loss: 0.2772 - accuracy: 0.9169 - val_loss: 0.2781 - val_accuracy: 0.9087
# Epoch 10/15
# 55/55 [==============================] - 49s 900ms/step - loss: 0.2627 - accuracy: 0.9111 - val_loss: 0.2632 - val_accuracy: 0.9043
# Epoch 11/15
# 55/55 [==============================] - 50s 907ms/step - loss: 0.2797 - accuracy: 0.9007 - val_loss: 0.2523 - val_accuracy: 0.9174
# Epoch 12/15
# 55/55 [==============================] - 50s 908ms/step - loss: 0.2420 - accuracy: 0.9215 - val_loss: 0.2587 - val_accuracy: 0.9174
# Epoch 13/15
# 55/55 [==============================] - 51s 925ms/step - loss: 0.2153 - accuracy: 0.9353 - val_loss: 0.2419 - val_accuracy: 0.9174
# Epoch 14/15
# 55/55 [==============================] - 51s 923ms/step - loss: 0.2290 - accuracy: 0.9284 - val_loss: 0.2412 - val_accuracy: 0.9174
# Epoch 15/15
# 55/55 [==============================] - 50s 909ms/step - loss: 0.2421 - accuracy: 0.9157 - val_loss: 0.2457 - val_accuracy: 0.9261

# %% [markdown]
# ## Model Evaluation

# %%
# Function for showing plot of model
def plot_loss_curves(history):
  loss = history.history['loss']
  val_loss = history.history['val_loss']

  accuracy = history.history['accuracy']
  val_accuracy = history.history['val_accuracy']

  epochs = range(len(loss))

  plt.plot(epochs, loss, label='training_loss')
  plt.plot(epochs, val_loss, label='val_loss')
  plt.title("Loss Curves")
  plt.xlabel("Epochs")
  plt.legend()

  plt.figure()
  plt.plot(epochs, accuracy, label='training_accuracy')
  plt.plot(epochs, val_accuracy, label='val_accuracy')
  plt.title("Accuracy Curves")
  plt.xlabel("Epochs")
  plt.legend()

# %%
# Show the plot of model
plot_loss_curves(history)

# %%
# Evaluation
model.evaluate(valid_data)
# Out:
# 15/15 [==============================] - 9s 575ms/step - loss: 0.2457 - accuracy: 0.9261
# [0.24567562341690063, 0.926086962223053]

# %%
# classification report
val_pred = model.predict(valid_data)
val_pred = val_pred.argmax(axis=1)
print(classification_report(val_pred, val_y))
# Out:
#               precision    recall  f1-score   support
#
#            0       0.91      0.99      0.95        81
#            1       0.89      0.92      0.91        64
#            2       0.97      0.87      0.92        85
#
#     accuracy                           0.93       230
#    macro avg       0.93      0.93      0.92       230
# weighted avg       0.93      0.93      0.93       230

# %%
# confusion matrix
val_pred = model.predict(valid_data)
val_pred = val_pred.argmax(axis=1)
cfm_val = confusion_matrix(val_pred, val_y)
ax = sns.heatmap(cfm_val, annot=True, cmap='Blues')

# Preparation for plotting confusion matrix
ax.set_title('Confusion Matrix with labels\n\n');
ax.set_xlabel('\nPredicted Values')
ax.set_ylabel('Actual Values ');

## Display the visualization of the Confusion Matrix.
plt.show()

# %% [markdown]
# ## Model Inference using Test Data

# %%
# classification report
test_pred = model.predict(test_data)
test_pred = test_pred.argmax(axis=1)
print(classification_report(test_pred, test_y))
# Out:
#               precision    recall  f1-score   support
#
#            0       0.86      0.95      0.90        20
#            1       0.94      0.85      0.89        20
#            2       0.95      0.95      0.95        20
#
#     accuracy                           0.92        60
#    macro avg       0.92      0.92      0.92        60
# weighted avg       0.92      0.92      0.92        60

# %%
# confusion matrix
cfm_test = confusion_matrix(test_pred, test_y)
ax = sns.heatmap(cfm_test, annot=True, 
            cmap='Blues')

# Preparation for plotting confusion matrix
ax.set_title('Confusion Matrix with labels\n\n');
ax.set_xlabel('\nPredicted Values')
ax.set_ylabel('Actual Values ');

## Display the visualization of the Confusion Matrix.
plt.show()

# %% [markdown]
# ## Model Inference using Custom Data

# %% [markdown]
# ### Nitrogen (N)

# %% [markdown]
# #### First Image

# %%
# Load image
n1 = tf.keras.preprocessing.image.load_img("/content/drive/MyDrive/N-1.jpg", target_size=(224, 224))
n1
# Out:
# <PIL.Image.Image image mode=RGB size=224x224 at 0x7FB67AB1AC90>

# %%
# Convert Image and Prediction
n1_arr = tf.keras.preprocessing.image.img_to_array(n1)
n1_arr = np.array([n1_arr])  # Convert single image to a batch.
n1_arr = n1_arr.astype('float32') / 255
n1_pred = model.predict(n1_arr).argmax(axis=1)
n1_pred_res = []
for i,j in label_indices.items():
  if n1_pred==j:
    n1_pred_res.append(i)

n1_pred_res
# Out:
# ['Potassium(K)']

# %% [markdown]
# #### Second Image

# %%
# Load image
n2 = tf.keras.preprocessing.image.load_img("/content/drive/MyDrive/N-2.jpg", target_size=(224, 224))
n2
# Out:
# <PIL.Image.Image image mode=RGB size=224x224 at 0x7FB67AA5CF10>

# %%
# Convert Image and Prediction
n2_arr = tf.keras.preprocessing.image.img_to_array(n2)
n2_arr = np.array([n2_arr])  # Convert single image to a batch.
n2_arr = n2_arr.astype('float32') / 255
n2_pred = model.predict(n2_arr).argmax(axis=1)
n2_pred_res = []
for i,j in label_indices.items():
  if n2_pred==j:
    n2_pred_res.append(i)

n2_pred_res
# Out:
# ['Nitrogen(N)']

# %% [markdown]
# #### Third Image

# %%
# Load image
n3 = tf.keras.preprocessing.image.load_img("/content/drive/MyDrive/N-3.jpg", target_size=(224, 224))
n3
# Out:
# <PIL.Image.Image image mode=RGB size=224x224 at 0x7FB67AFF8DD0>

# %%
# Convert Image and Prediction
n3_arr = tf.keras.preprocessing.image.img_to_array(n3)
n3_arr = np.array([n3_arr])  # Convert single image to a batch.
n3_arr = n3_arr.astype('float32') / 255
n3_pred = model.predict(n3_arr).argmax(axis=1)
n3_pred_res = []
for i,j in label_indices.items():
  if n3_pred==j:
    n3_pred_res.append(i)

n3_pred_res
# Out:
# ['Nitrogen(N)']

# %% [markdown]
# ### Phosphorus (P)

# %% [markdown]
# #### First Image

# %%
# Load image
p1 = tf.keras.preprocessing.image.load_img("/content/drive/MyDrive/P-1.jpg", target_size=(224, 224))
p1
# Out:
# <PIL.Image.Image image mode=RGB size=224x224 at 0x7FB7637D4310>

# %%
# Convert Image and Prediction
p1_arr = tf.keras.preprocessing.image.img_to_array(p1)
p1_arr = np.array([p1_arr])  # Convert single image to a batch.
p1_arr = p1_arr.astype('float32') / 255
p1_pred = model.predict(p1_arr).argmax(axis=1)
p1_pred_res = []
for i,j in label_indices.items():
  if p1_pred==j:
    p1_pred_res.append(i)

p1_pred_res
# Out:
# ['Phosphorus(P)']

# %% [markdown]
# #### Second Image

# %%
# Load image
p2 = tf.keras.preprocessing.image.load_img("/content/drive/MyDrive/P-2.jpg", target_size=(224, 224))
p2
# Out:
# <PIL.Image.Image image mode=RGB size=224x224 at 0x7FB6795F6D10>

# %%
# Convert Image and Prediction
p2_arr = tf.keras.preprocessing.image.img_to_array(p2)
p2_arr = np.array([p2_arr])  # Convert single image to a batch.
p2_arr = p2_arr.astype('float32') / 255
p2_pred = model.predict(p2_arr).argmax(axis=1)
p2_pred_res = []
for i,j in label_indices.items():
  if p2_pred==j:
    p2_pred_res.append(i)

p2_pred_res
# Out:
# ['Potassium(K)']

# %% [markdown]
# #### Third Image

# %%
# Load image
p3 = tf.keras.preprocessing.image.load_img("/content/drive/MyDrive/P-3.jpg", target_size=(224, 224))
p3
# Out:
# <PIL.Image.Image image mode=RGB size=224x224 at 0x7FB6795F8750>

# %%
# Convert Image and Prediction
p3_arr = tf.keras.preprocessing.image.img_to_array(p3)
p3_arr = np.array([p3_arr])  # Convert single image to a batch.
p3_arr = p3_arr.astype('float32') / 255
p3_pred = model.predict(p3_arr).argmax(axis=1)
p3_pred_res = []
for i,j in label_indices.items():
  if p3_pred==j:
    p3_pred_res.append(i)

p3_pred_res
# Out:
# ['Potassium(K)']

# %% [markdown]
# ### Potassium (K)

# %% [markdown]
# #### First Image

# %%
# Load image
k1 = tf.keras.preprocessing.image.load_img("/content/drive/MyDrive/K-1.jpg", target_size=(224, 224))
k1
# Out:
# <PIL.Image.Image image mode=RGB size=224x224 at 0x7FB6E7D6DD90>

# %%
# Convert Image and Prediction
k1_arr = tf.keras.preprocessing.image.img_to_array(k1)
k1_arr = np.array([k1_arr])  # Convert single image to a batch.
k1_arr = k1_arr.astype('float32') / 255
k1_pred = model.predict(k1_arr).argmax(axis=1)
k1_pred_res = []
for i,j in label_indices.items():
  if k1_pred==j:
    k1_pred_res.append(i)

k1_pred_res
# Out:
# ['Potassium(K)']

# %% [markdown]
# #### Second Image

# %%
# Load image
k2 = tf.keras.preprocessing.image.load_img("/content/drive/MyDrive/K-2.jpg", target_size=(224, 224))
k2
# Out:
# <PIL.Image.Image image mode=RGB size=224x224 at 0x7FB6E7D7F7D0>

# %%
# Convert Image and Prediction
k2_arr = tf.keras.preprocessing.image.img_to_array(k2)
k2_arr = np.array([k2_arr])  # Convert single image to a batch.
k2_arr = k2_arr.astype('float32') / 255
k2_pred = model.predict(k2_arr).argmax(axis=1)
k2_pred_res = []
for i,j in label_indices.items():
  if k2_pred==j:
    k2_pred_res.append(i)

k2_pred_res
# Out:
# ['Potassium(K)']

# %% [markdown]
# #### Third Image

# %%
# Load image
k3 = tf.keras.preprocessing.image.load_img("/content/drive/MyDrive/K-3.jpg", target_size=(224, 224))
k3
# Out:
# <PIL.Image.Image image mode=RGB size=224x224 at 0x7FB6E7D3A550>

# %%
# Convert Image and Prediction
k3_arr = tf.keras.preprocessing.image.img_to_array(k3)
k3_arr = np.array([k3_arr])  # Convert single image to a batch.
k3_arr = k3_arr.astype('float32') / 255
k3_pred = model.predict(k3_arr).argmax(axis=1)
k3_pred_res = []
for i,j in label_indices.items():
  if k3_pred==j:
    k3_pred_res.append(i)

k3_pred_res
# Out:
# ['Potassium(K)']

# %% [markdown]
# ### Model Saving

# %%
model.save('model')
# Out:
# INFO:tensorflow:Assets written to: model/assets

# %%
# !zip -r /content/model.zip /content/model
# Out:
#   adding: content/model/ (stored 0%)
#   adding: content/model/keras_metadata.pb (deflated 96%)
#   adding: content/model/assets/ (stored 0%)
#   adding: content/model/variables/ (stored 0%)
#   adding: content/model/variables/variables.index (deflated 78%)
#   adding: content/model/variables/variables.data-00000-of-00001 (deflated 7%)
#   adding: content/model/saved_model.pb (deflated 92%)

# %%
tf.keras.models.save_model(
    model, 'model.hdf5')
